# %% [markdown]
# # Using GEE to create a large set of analysis-ready data in tabular format
#
# Before running this code, run script 01 to create the biotic stacks and then upload the results to GEE (as well as other disturbance stack stuff)
#
# NOTES
#
# ~6 hrs to run exports for IDB & SR at 1000m sample with new code

# %%
import os

import ee
import geemap.foliumap as geemap
import geemap

from find_set_root import find_set_project_root
PROJECT_ROOT = find_set_project_root()
print(f"Project root found at: {PROJECT_ROOT}")
import utils.general_functions as ugf


DIR_RAW = os.path.join(PROJECT_ROOT, 'data', 'raw')
DIR_DERIVED = os.path.join(PROJECT_ROOT, 'data', 'derived')
ugf.dir_ensure([DIR_RAW, DIR_DERIVED])

GEE_PROJECT = 'ee-tymc5571-multi-disturbance'
DRIVE_FOLDER = "GEE_Exports_resilience_20251130"

#Prepare to use Earth Engine
ee.Authenticate(
    auth_mode='notebook',
    scopes=[
        'https://www.googleapis.com/auth/earthengine',
        'https://www.googleapis.com/auth/devstorage.read_write',
        'https://www.googleapis.com/auth/drive'
    ]
)
ee.Initialize(project=GEE_PROJECT)

SERVICE_FILE = "C:/Users/tymc5571/dev/cbi-module/config/secrets/tymc5571-utils-project-692f27c034dd.json"  # Path to service account file


#############
# USER SET PARAMETERS
#############

TARGET_CRS = 'EPSG:5070'  # Albers Equal Area - selected since working in W.US
SCALE = 250  # in meters - approximate MODIS resolution
MINIMUM_FOREST_PERC_PIXEL = 0.50  # minimum percent of coarse forest at pixel to be included
MINIMUM_FIRE_PERC_PIXEL = 0.25  # minimum percent of pixel within fire perimeter to be included as a burnt pixel
MINIMUM_USFS_PERC_PIXEL = 0.95  # minimum percent of pixel within USFS to be included in data

# Setup aoi
# AOI_REGION = '6.2.14'
# AOI_READABLE = "SRockies"

AOI_REGION = '6.2.15'
AOI_READABLE = "IDBatholith"

# AOI_REGION = '6.2.12'
# AOI_READABLE = "SierraNevada"

# AOI_REGION = '6.2.5'
# AOI_READABLE = "NCascades"

#AOI_READABLE = "test"

COARSE_FOREST_PERC_MIN = 0
COARSE_TRE_MAX_MIN = 25

FOREST_RANDOM_SAMPLE = 0.2
RANDOM_SEED = 1234
TILE_SIZE = 10000 #100000 & 1000 works well
SAMPLE_SCALE = 500  # in meters
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Project root found at: C:\Users\tymc5571\dev\compound-disturbance-resilience
# ✅ Directory already exists: C:\Users\tymc5571\dev\compound-disturbance-resilience\data\raw
# ✅ Directory already exists: C:\Users\tymc5571\dev\compound-disturbance-resilience\data\derived

# %%
# Load datasets
chili = ee.Image("CSP/ERGo/1_0/US/CHILI")
lcms = ee.ImageCollection("USFS/GTAC/LCMS/v2024-10")
lcmap = ee.ImageCollection("projects/sat-io/open-datasets/LCMAP/LCPRI")
conservative_forest_annual = ee.Image("projects/ee-tymc5571-cbi-module/assets/conservative_forest_1985_2024")
frg = ee.ImageCollection("LANDFIRE/Fire/FRG/v1_2_0")
tpi = ee.Image("CSP/ERGo/1_0/US/mTPI")
terraclimate = ee.ImageCollection("IDAHO_EPSCOR/TERRACLIMATE")
topoterra_early = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/TopoTerra_1961-1990")
topoterra_later = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/TopoTerra_1985-2015")
topoterra_normals = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/TopoTerra_1961-2022")
topoterra_future = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/TopoTerra_2C_1985-2015")
srtm = ee.Image("USGS/SRTMGL1_003")
cbi = ee.Image("projects/ee-tymc5571-goodfire/assets/welty_wildfire_cbi_bc_1985_2020")
rap = ee.ImageCollection("projects/rap-data-365417/assets/vegetation-cover-v3")
modis = ee.ImageCollection("MODIS/061/MOD44B")
nfg = ee.ImageCollection("projects/sat-io/open-datasets/USFS/national-forest-group")
biotic = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/biotic_gridded_1km_all_years_severity")
vcf = ee.ImageCollection("MODIS/061/MOD44B")
hd_fingerprint = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_warm_fingerprint")
hd_z_def = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_def")
hd_z_pdsi = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_pdsi")
hd_z_vpd = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_vpd")
hd_z_tmmx = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_tmmx")
hd_z_soil = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_soil")  
hd_z_pr = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/hd_zscores_pr")
epa_lvl3 = ee.FeatureCollection("EPA/Ecoregions/2013/L3")
epa_lvl4 = ee.FeatureCollection("EPA/Ecoregions/2013/L4")
fire_ids = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/welty_fire_ids")
usfs = ee.Image("projects/ee-tymc5571-multi-disturbance/assets/usfs_binary")


# AOI
states = ee.FeatureCollection("TIGER/2018/States")

aoi = epa_lvl3.filter(ee.Filter.eq('na_l3code', AOI_REGION))
# aoi= states.filter(ee.Filter.eq('STUSPS', 'CO'))
# aoi = ee.Geometry.Rectangle(
#     coords=[-105.545, 39.948, -105.445, 40.038],  # [xmin, ymin, xmax, ymax]
#     proj=None,
#     geodesic=False
# )
print(aoi.getInfo())

##########################

#Add CBI prefix if not present
cbi = cbi.rename(
    cbi.bandNames().map(
        lambda n: ee.Algorithms.If(
            ee.String(n).slice(0, 4).compareTo('cbi_').eq(0),
            n,
            ee.String('cbi_').cat(n)
        )
    )
)

# The temporal AOI will be based on the years in the CBI data selected
years = cbi.bandNames().map(lambda b: ee.Number.parse(ee.String(b).split('_').get(2)))
print(years.getInfo())
CBI_START_YEAR = ee.Number(years.sort().get(0)).getInfo()
CBI_END_YEAR = ee.Number(years.sort().get(-1)).getInfo()
print(CBI_START_YEAR, CBI_END_YEAR)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection', 'columns': {'l1_key': 'String', 'l2_key': 'String', 'l3_key': 'String', 'na_l1code': 'String', 'na_l1name': 'String', 'na_l2code': 'String', 'na_l2name': 'String', 'na_l3code': 'String', 'na_l3name': 'String', 'shape_area': 'Float', 'shape_leng': 'Float', 'system:index': 'String', 'us_l3code': 'String', 'us_l3name': 'String'}, 'version': 1566852390239791, 'id': 'EPA/Ecoregions/2013/L3', 'properties': {'date_range': [1366070400000, 1366156800000], 'period': 0, 'thumb': 'https://mw1.google.com/ges/dd/images/Ecoregions_thumb.png', 'description': '<p>The U.S. Environmental Protection Agency (USEPA) provides\nthe Ecoregions dataset to serve as a spatial framework for the\nresearch, assessment, management, and monitoring of ecosystems\nand ecosystem components. Ecoregions denote areas of general\nsimilarity in ecosystems and in the type, quality, and quantity\nof environmental resources. These general-purpose regions are\ncritical for structuring and implementing ecosystem management\nstrategies across federal agencies, state agencies, and nongovernmental\norganizations that are responsible for different types of resources\nwithin the same geographical areas.</p><p>The approach used to\ncompile this map is based on the premise that ecological regions\ncan be identified through the analysis of patterns of biotic\nand abiotic phenomena, including geology, physiography, vegetation,\nclimate, soils, land use, wildlife, and hydrology. The relative\nimportance of each characteristic varies from one ecological\nregion to another.</p><p>This dataset includes the USEPA ecoregions\nclassification scheme, as well as the scheme from the Commission\nfor Environmental Cooperation (CEC). Ecoregions are hierarchical,\nwith Level IV being the most detailed and Level I defining the\nbroadest classifications. Because of this hierarchy, Level III\nfeatures retain information from Levels I and II. The CEC divided\nall of North America in distinct ecoregions for Levels I, II,\nand III, while the USEPA did so only for the United States at\nLevel III and Level IV. The columns starting with \'us_\' belong\nto the USEPA scheme, and the columns starting with \'na_\' belong\nto the CEC scheme. The ingested version of this dataset contains\nfeatures for the conterminous United States only (that is, Alaska\nand Hawaii are not included). Methods used to define the ecoregions\nare explained in Omernik (1995, 2004), Omernik and others (2000),\nand Gallant and others (1989)."</p><p><b>Table Schema</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Type</th><th scope="col">Description</th></tr><tr><td>l1_key</td><td>STRING</td><td><p>NA Level I Code and Name</p></td></tr><tr><td>l2_key</td><td>STRING</td><td><p>NA Level II Code and Name</p></td></tr><tr><td>l3_key</td><td>STRING</td><td><p>US Level III Code and Name</p></td></tr><tr><td>na_l1code</td><td>STRING</td><td><p>Code for Level I Ecoregion (North America/CEC)</p></td></tr><tr><td>na_l1name</td><td>STRING</td><td><p>Name for Level I Ecoregion (North America/CEC)</p></td></tr><tr><td>na_l2code</td><td>STRING</td><td><p>Code for Level II Ecoregion (North America/CEC)</p></td></tr><tr><td>na_l2name</td><td>STRING</td><td><p>Name for Level II Ecoregion (North America/CEC)</p></td></tr><tr><td>na_l3code</td><td>STRING</td><td><p>Code for Level III Ecoregion (North America/CEC)</p></td></tr><tr><td>na_l3name</td><td>STRING</td><td><p>Name for Level III Ecoregion (North America/CEC)</p></td></tr><tr><td>shape_area*</td><td>DOUBLE</td><td><p>Area of the feature\'s geometry in its original format</p></td></tr><tr><td>shape_leng*</td><td>DOUBLE</td><td><p>Length of the edges in the feature\'s geometry in its original format</p></td></tr><tr><td>us_l3code</td><td>STRING</td><td><p>Code for Level III Ecoregion (US/USEPA)</p></td></tr><tr><td>us_l3name</td><td>STRING</td><td><p>Name for Level III Ecoregion (US/USEPA)</p></td></tr></table><p><sup>*Calculated by the data provi ...
# [1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 1985 2020

# %%
from typing import Literal, Any


# Utility functions

# -------------------------------
# Reclassify an image and mask all values except a specific value (e.g., forest class)
def reclassify_image_binary(value):
    def _reclassify(image):
        binary = image.eq(value).selfMask()
        return binary.copyProperties(image, ['system:time_start'])
    return _reclassify

# -------------------------------
# Combine two collections using logical AND (per image pair), copying time from the first image
def combine_collections_with_and(collection1, collection2, and_name):
    list1 = collection1.toList(collection1.size())
    list2 = collection2.toList(collection2.size())
    combined = list1.zip(list2)

    def combine_pair(pair):
        image1 = ee.Image(ee.List(pair).get(0))
        image2 = ee.Image(ee.List(pair).get(1))
        and_result = image1.And(image2).rename(and_name)
        return and_result.copyProperties(image1, ['system:time_start'])

    return ee.ImageCollection(combined.map(combine_pair))

# -------------------------------
# Add a 'year' property to each image
def add_year_property(image):
    year = image.date().get('year')
    return image.set('year', year)



def resample_to_coarse(source, coarse_image, reducer, max_pixels=4000):
    proj = coarse_image.projection()

    def reduce_and_reproject(img):
        img = img.setDefaultProjection(img.projection())
        return img.reduceResolution(
            reducer=reducer,
            maxPixels=max_pixels
        ).reproject(proj)

    return source.map(reduce_and_reproject) if isinstance(source, ee.ImageCollection) else reduce_and_reproject(source)



def moving_window(
    image: ee.Image,
    window_size: int | float,
    reducer: ee.Reducer,
    kernel_shape: Literal[
        'square', 'circle', 'rect', 'cross', 'gaussian', 'manhattan', 'chebyshev'
    ] = 'square',
    keep_original_bandnames: bool = False,
    **kwargs: Any
) -> ee.Image:
    """
    Apply a moving window operation on an image using a specified reducer, window size, and kernel shape.

    Parameters:
    - image: ee.Image
    - window_size: int or float, diameter in meters
    - reducer: ee.Reducer (e.g., ee.Reducer.mean())
    - kernel_shape: One of ['square', 'circle', 'rect', 'cross', 'gaussian', 'manhattan', 'chebyshev']
    - keep_original_bandnames: If True, retain the original band names after filtering
    - kwargs: Additional parameters:
        - 'xRadius', 'yRadius' for 'rect'
        - 'sigma' for 'gaussian'
        - 'normalize' (bool) for all kernels (default: False)

    Returns:
    - ee.Image: Result of the focal/moving window operation
    """
    normalize: bool = kwargs.get('normalize', False)

    if kernel_shape == 'square':
        kernel = ee.Kernel.square(radius=window_size / 2, units='meters', normalize=normalize)
    elif kernel_shape == 'circle':
        kernel = ee.Kernel.circle(radius=window_size / 2, units='meters', normalize=normalize)
    elif kernel_shape == 'rect':
        xRadius = kwargs.get('xRadius', window_size / 2)
        yRadius = kwargs.get('yRadius', window_size / 2)
        kernel = ee.Kernel.rect(xRadius=xRadius, yRadius=yRadius, units='meters', normalize=normalize)
    elif kernel_shape == 'cross':
        kernel = ee.Kernel.cross(radius=window_size / 2, units='meters', normalize=normalize)
    elif kernel_shape == 'gaussian':
        sigma = kwargs.get('sigma', window_size / 6)
        kernel = ee.Kernel.gaussian(radius=window_size / 2, sigma=sigma, units='meters', normalize=normalize)
    elif kernel_shape == 'manhattan':
        kernel = ee.Kernel.manhattan(radius=window_size / 2, units='meters', normalize=normalize)
    elif kernel_shape == 'chebyshev':
        kernel = ee.Kernel.chebyshev(radius=window_size / 2, units='meters', normalize=normalize)
    else:
        raise ValueError(f"Unsupported kernel shape: {kernel_shape}")

    result = image.reduceNeighborhood(reducer=reducer, kernel=kernel)

    if keep_original_bandnames:
        original_names = image.bandNames()
        result = result.rename(original_names)

    return result


def remove_to_bands_append(image):
    """
    Renames bands in the input Earth Engine Image by removing the first part
    (before the first underscore) from each band name.

    Args:
        image (ee.Image): The input image.

    Returns:
        ee.Image: The image with renamed bands.
    """
    old_names = image.bandNames()
    new_names = old_names.map(lambda name: ee.String(name).split('_').slice(1).join('_'))
    return image.rename(new_names)


def remove_to_bands_append2(image, og_ic):
    """
    Removes image ID prefixes (from toBands()) using IDs from the original ImageCollection.
    
    Args:
        image (ee.Image): The image with compound band names after toBands().
        og_ic (ee.ImageCollection): The original ImageCollection before stacking.
    
    Returns:
        ee.Image: Image with cleaned band names.
    """
    ids = ee.List(og_ic.aggregate_array('system:index'))

    def clean_name(name):
        name = ee.String(name)
        def iterate_fn(id_, acc):
            acc_str = ee.String(acc)
            id_str = ee.String(id_).cat('_')
            match = acc_str.slice(0, id_str.length()).equals(id_str)
            return ee.Algorithms.If(match, acc_str.slice(id_str.length()), acc_str)
        return ids.iterate(iterate_fn, name)

    old_names = image.bandNames()
    new_names = old_names.map(lambda b: clean_name(b))
    return image.rename(new_names)

def prepend_or_append_to_band_names(
    image: ee.Image,
    text: str,
    mode: Literal["APPEND", "PREPEND"]
) -> ee.Image:
    """
    Appends or prepends a string to all band names of the given Earth Engine image.

    Args:
        image (ee.Image): The input Earth Engine image.
        text (str): The string to append or prepend.
        mode (Literal["APPEND", "PREPEND"]): Specifies whether to append or prepend the string.

    Returns:
        ee.Image: Image with updated band names.
    """
    old_names = image.bandNames()

    if mode == "APPEND":
        new_names = old_names.map(lambda name: ee.String(name).cat(text))
    elif mode == "PREPEND":
        new_names = old_names.map(lambda name: ee.String(text).cat(name))
    else:
        # This should never be reached due to Literal type, but it's good practice
        raise ValueError("Mode must be either 'APPEND' or 'PREPEND'")

    return image.rename(new_names)


def insert_to_band_names(image: ee.Image, text: str, index: int) -> ee.Image:
    """
    Inserts a string into each band name of an Earth Engine image at the specified index.
    
    Args:
        image (ee.Image): The input image.
        text (str): The string to insert.
        index (int): The character index at which to insert the string.
                     Supports negative indexing from the end.
    
    Returns:
        ee.Image: Image with updated band names.
    """
    def insert_at(name):
        name_str = ee.String(name)
        name_len = name_str.length()
        
        # Compute final insertion index (accounting for negative values)
        insert_pos = ee.Algorithms.If(
            index >= 0,
            ee.Number(index),
            name_len.add(index)  # index is negative, so subtract from length
        )
        insert_pos = ee.Number(insert_pos).clamp(0, name_len)  # avoid out-of-bounds
        
        prefix = name_str.slice(0, insert_pos)
        suffix = name_str.slice(insert_pos)
        return prefix.cat(text).cat(suffix)

    old_names = image.bandNames()
    new_names = old_names.map(insert_at)
    return image.rename(new_names)

def toBands_with_projection(collection):
    collection = ee.ImageCollection(collection)
    image = collection.toBands()
    reference_img = ee.Image(collection.first())
    return image.setDefaultProjection(reference_img.projection())

def filter_bands_by_year(image: ee.Image, first_year: int, last_year: int) -> ee.Image:
    band_names = image.bandNames()

    # Create list of allowed years as strings
    allowed_years = ee.List.sequence(first_year, last_year).map(
        lambda y: ee.Number(y).format('%04d')
    )

    # Map over band names and keep only those that match an allowed year suffix
    def keep_if_valid(band):
        band_str = ee.String(band)
        year_suffix = band_str.slice(-4)
        return ee.Algorithms.If(
            allowed_years.contains(year_suffix),
            band_str,
            None
        )

    # Map and filter out None
    valid_bands = band_names.map(keep_if_valid).removeAll([None])

    return image.select(valid_bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#################################
# PREP RESPONSE DATASETS
# Rename bands to include source and year with form vcf_tree_2001 or rap_tree_2015
#################################

####################
# MODIS VCF
####################

def rename_vcf(img):
    year = img.date().format('YYYY')
    new_names = img.bandNames().map(lambda b: ee.String('modis_').cat(b).cat('_').cat(year))
    return img.rename(new_names)

modis_vcf = vcf.select(['Percent_Tree_Cover', 'Percent_Tree_Cover_SD'])
renamed_modis_vcf = modis_vcf.map(rename_vcf)
modis_vcf_im = toBands_with_projection(renamed_modis_vcf)


modis_vcf_im = remove_to_bands_append2(modis_vcf_im, og_ic = renamed_modis_vcf)
modis_og_names = modis_vcf_im.bandNames().getInfo()
modis_new_names = [n.replace("modis_Percent_Tree_Cover", "vcf_tree")
             for n in modis_og_names]
modis_vcf_im = modis_vcf_im.rename(modis_new_names)

print(modis_vcf_im.bandNames().getInfo())

modis_projection = modis_vcf_im.projection()
modis_scale = modis_projection.nominalScale()
print(f"MODIS VCF scale: {modis_scale.getInfo()} meters")
print(modis_projection.getInfo())

vcf_5070 = (modis_vcf_im
            .reproject(
                crs=TARGET_CRS,
                scale=SCALE
            ))

###################
# RAP
###################

def rename_rap(img):
    year = ee.String(img.id().split('/').get(-1))
    new_names = img.bandNames().map(lambda b: ee.String('rap_').cat(b).cat('_').cat(year))
    return img.rename(new_names)

renamed_rap = rap.map(rename_rap)
rap_mosaic = toBands_with_projection(renamed_rap)
fixed_rap_names = rap_mosaic.bandNames().map(lambda b: ee.String(b).slice(5))
rap_mosaic = rap_mosaic.rename(fixed_rap_names)

rap_og_names = rap_mosaic.bandNames().getInfo()
rap_new_names = [n.replace("TRE", "tree") for n in rap_og_names]
rap_mosaic = rap_mosaic.rename(rap_new_names)

# Filter tree bands
tre_bands = rap_mosaic.bandNames().filter(ee.Filter.stringContains('item', 'tree'))
rap_mosaic = rap_mosaic.select(tre_bands)

print(rap_mosaic.bandNames().getInfo())

# Reduce RAP resolution to match MODIS VCF (250m)
rap_5070 = rap_mosaic.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs = TARGET_CRS,
    scale=SCALE
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['vcf_tree_2000', 'vcf_tree_SD_2000', 'vcf_tree_2001', 'vcf_tree_SD_2001', 'vcf_tree_2002', 'vcf_tree_SD_2002', 'vcf_tree_2003', 'vcf_tree_SD_2003', 'vcf_tree_2004', 'vcf_tree_SD_2004', 'vcf_tree_2005', 'vcf_tree_SD_2005', 'vcf_tree_2006', 'vcf_tree_SD_2006', 'vcf_tree_2007', 'vcf_tree_SD_2007', 'vcf_tree_2008', 'vcf_tree_SD_2008', 'vcf_tree_2009', 'vcf_tree_SD_2009', 'vcf_tree_2010', 'vcf_tree_SD_2010', 'vcf_tree_2011', 'vcf_tree_SD_2011', 'vcf_tree_2012', 'vcf_tree_SD_2012', 'vcf_tree_2013', 'vcf_tree_SD_2013', 'vcf_tree_2014', 'vcf_tree_SD_2014', 'vcf_tree_2015', 'vcf_tree_SD_2015', 'vcf_tree_2016', 'vcf_tree_SD_2016', 'vcf_tree_2017', 'vcf_tree_SD_2017', 'vcf_tree_2018', 'vcf_tree_SD_2018', 'vcf_tree_2019', 'vcf_tree_SD_2019', 'vcf_tree_2020', 'vcf_tree_SD_2020', 'vcf_tree_2021', 'vcf_tree_SD_2021', 'vcf_tree_2022', 'vcf_tree_SD_2022', 'vcf_tree_2023', 'vcf_tree_SD_2023', 'vcf_tree_2024', 'vcf_tree_SD_2024']
# MODIS VCF scale: 231.65635826395828 meters
# {'type': 'Projection', 'crs': 'SR-ORG:6974', 'transform': [231.65635826395825, 0, -20015109.354, 0, -231.65635826395834, 10007554.677003]}
# ['rap_tree_1986', 'rap_tree_1987', 'rap_tree_1988', 'rap_tree_1989', 'rap_tree_1990', 'rap_tree_1991', 'rap_tree_1992', 'rap_tree_1993', 'rap_tree_1994', 'rap_tree_1995', 'rap_tree_1996', 'rap_tree_1997', 'rap_tree_1998', 'rap_tree_1999', 'rap_tree_2000', 'rap_tree_2001', 'rap_tree_2002', 'rap_tree_2003', 'rap_tree_2004', 'rap_tree_2005', 'rap_tree_2006', 'rap_tree_2007', 'rap_tree_2008', 'rap_tree_2009', 'rap_tree_2010', 'rap_tree_2011', 'rap_tree_2012', 'rap_tree_2013', 'rap_tree_2014', 'rap_tree_2015', 'rap_tree_2016', 'rap_tree_2017', 'rap_tree_2018', 'rap_tree_2019', 'rap_tree_2020', 'rap_tree_2021', 'rap_tree_2022', 'rap_tree_2023', 'rap_tree_2024']

# %%
#########################
# PREP BIOTIC DATA
#########################

# BIOTIC
# Load the image asset

#print("Available bands:", biotic.bandNames().getInfo())
new_biotic_names = [f'biotic_{year}' for year in range(1997, 2024)]
biotic = biotic.rename(new_biotic_names)

# Create summed biotic layers
biotic_timeseries_sum = biotic.reduce(ee.Reducer.sum()).rename('biotic_timeseries_sum')

biotic_with_sum = biotic.addBands(biotic_timeseries_sum)
biotic_5070 = (biotic_with_sum
.reproject(
    crs=TARGET_CRS,
    scale=1000
))

print("Renamed biotic bands:", biotic_5070.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Renamed biotic bands: ['biotic_1997', 'biotic_1998', 'biotic_1999', 'biotic_2000', 'biotic_2001', 'biotic_2002', 'biotic_2003', 'biotic_2004', 'biotic_2005', 'biotic_2006', 'biotic_2007', 'biotic_2008', 'biotic_2009', 'biotic_2010', 'biotic_2011', 'biotic_2012', 'biotic_2013', 'biotic_2014', 'biotic_2015', 'biotic_2016', 'biotic_2017', 'biotic_2018', 'biotic_2019', 'biotic_2020', 'biotic_2021', 'biotic_2022', 'biotic_2023', 'biotic_timeseries_sum']

# %%
##################
# PREP FOREST DATA
##################

###################
# Relaxed forest mask
###################

lcmap_cover = lcmap.filterDate(str(CBI_START_YEAR - 1), str(CBI_END_YEAR))
lcms_cover = lcms.filter(ee.Filter.eq('study_area', 'CONUS')).filterDate(str(CBI_START_YEAR - 1), str(CBI_END_YEAR)).select('Land_Cover')

lcmap_for = lcmap_cover.map(reclassify_image_binary(4))
lcms_for = lcms_cover.map(reclassify_image_binary(1))

combined_forest_mask = lcmap_for.map(lambda img: img.reduce(ee.Reducer.max()).gt(0)).max().Or(
    lcms_for.map(lambda img: img.reduce(ee.Reducer.max()).gt(0)).max()
)
combined_forest = (combined_forest_mask
                        .unmask(0)
                        .rename('forest')
                        .setDefaultProjection(lcmap_cover.first().projection())
)

combined_forest_perc_5070 = combined_forest.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

combined_forest_mask_5070 = (combined_forest_perc_5070
                             .gte(MINIMUM_FOREST_PERC_PIXEL)
                             .selfMask()
                             .unmask(0))


###################
# Create distance from unburned forest the year after (conservative)
###################

cf_names = conservative_forest_annual.bandNames()

# Simply rename bands by subtracting one, e.g. from "forest_1985" to "forest_after_1984"
def rename_to_forest_after(b):
    b = ee.String(b)
    year = ee.Number.parse(b.split('_').get(1))
    new_year = year.subtract(1)
    return ee.String('forest_after_').cat(new_year.format())

new_names = cf_names.map(rename_to_forest_after)

conservative_forest_year_after = conservative_forest_annual.rename(new_names).reproject(
                    crs=TARGET_CRS,
                    scale=30
                )

print(conservative_forest_year_after.bandNames().getInfo())


pixel_size = ee.Number(30)

# Function to get the distance from unburned forest for a given year
# reprojection is done to ensure consistent pixel size of 30 m rather than relying on lazy evaluation
def get_unburned_distance(band_name):
    band_name = ee.String(band_name)
    band = conservative_forest_year_after.select([band_name])

    # Ensure the operation runs at 30 m
    band_30m = band.reproject(crs=TARGET_CRS, scale=pixel_size)

    # Distance^2 in pixels^2 to pixels
    dist_pixels = band_30m.fastDistanceTransform(
        neighborhood=256,
        units='pixels',
        metric='squared_euclidean'
    ).sqrt()

    # Pixels to meters
    dist_meters = dist_pixels.multiply(pixel_size)

    # Freeze the output at 30 m as well
    dist_meters_30m = dist_meters.reproject(crs=TARGET_CRS, scale=pixel_size)

    new_name = ee.String('distance_').cat(band_name)
    return dist_meters_30m.rename(new_name)

distance_ic = ee.ImageCollection(
    conservative_forest_year_after.bandNames().map(get_unburned_distance)
)

unburned_forest_distance = distance_ic.toBands()

# Enforce projection on the final image
unburned_forest_distance = unburned_forest_distance.reproject(
    crs=TARGET_CRS,
    scale=30
)

unburned_forest_distance = remove_to_bands_append(unburned_forest_distance)

print(unburned_forest_distance.bandNames().getInfo())
print(unburned_forest_distance.select(0).projection().getInfo())

unburned_forest_distance_5070 = (unburned_forest_distance
                                .reduceResolution(
                                    reducer=ee.Reducer.mean(),
                                    maxPixels=1024
                                ).reproject(
                                    crs=TARGET_CRS,
                                    scale=SCALE
                                ))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['forest_after_1984', 'forest_after_1985', 'forest_after_1986', 'forest_after_1987', 'forest_after_1988', 'forest_after_1989', 'forest_after_1990', 'forest_after_1991', 'forest_after_1992', 'forest_after_1993', 'forest_after_1994', 'forest_after_1995', 'forest_after_1996', 'forest_after_1997', 'forest_after_1998', 'forest_after_1999', 'forest_after_2000', 'forest_after_2001', 'forest_after_2002', 'forest_after_2003', 'forest_after_2004', 'forest_after_2005', 'forest_after_2006', 'forest_after_2007', 'forest_after_2008', 'forest_after_2009', 'forest_after_2010', 'forest_after_2011', 'forest_after_2012', 'forest_after_2013', 'forest_after_2014', 'forest_after_2015', 'forest_after_2016', 'forest_after_2017', 'forest_after_2018', 'forest_after_2019', 'forest_after_2020', 'forest_after_2021', 'forest_after_2022', 'forest_after_2023']
# ['distance_forest_after_1984', 'distance_forest_after_1985', 'distance_forest_after_1986', 'distance_forest_after_1987', 'distance_forest_after_1988', 'distance_forest_after_1989', 'distance_forest_after_1990', 'distance_forest_after_1991', 'distance_forest_after_1992', 'distance_forest_after_1993', 'distance_forest_after_1994', 'distance_forest_after_1995', 'distance_forest_after_1996', 'distance_forest_after_1997', 'distance_forest_after_1998', 'distance_forest_after_1999', 'distance_forest_after_2000', 'distance_forest_after_2001', 'distance_forest_after_2002', 'distance_forest_after_2003', 'distance_forest_after_2004', 'distance_forest_after_2005', 'distance_forest_after_2006', 'distance_forest_after_2007', 'distance_forest_after_2008', 'distance_forest_after_2009', 'distance_forest_after_2010', 'distance_forest_after_2011', 'distance_forest_after_2012', 'distance_forest_after_2013', 'distance_forest_after_2014', 'distance_forest_after_2015', 'distance_forest_after_2016', 'distance_forest_after_2017', 'distance_forest_after_2018', 'distance_forest_after_2019', 'distance_forest_after_2020', 'distance_forest_after_2021', 'distance_forest_after_2022', 'distance_forest_after_2023']
# {'type': 'Projection', 'crs': 'EPSG:5070', 'transform': [30, 0, 0, 0, -30, 0]}

# %%
nfg_5070 = (nfg
            .filter(ee.Filter.eq('id_no', 'conus_forestgroup'))
            .first()
            .select("b1")
            .rename('nfg')
            .reproject(
                crs=TARGET_CRS,
                scale=SCALE
            )
)

## NOTES TO SELF : could backfill NFG values where missing with a 1km modal kernel, 
# but won't do that now; check how many points we have to drop due to mising NFG
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#################################
# PREP MODERATOR DATSETS
#################################

###################
# CHILI, TPI, SRTM
###################

srtm_5070 = srtm.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

tpi_5070 = tpi.resample(
    mode='bilinear'
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

chili_5070 = chili.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

###################
# FRG
###################

# Reclassify FRG to simplify non-regime classes
frg_img = frg.filterMetadata('system:index', 'contains', 'CONUS').first()
frg_reclass = frg_img.remap(
    [1, 2, 3, 4, 5, 111, 112, 131, 132, 133],
    [1, 2, 3, 4, 5, 6, 6, 6, 6, 6],
    0, 'FRG'
).rename('frg_reclass')

frg_reclass_5070 = frg_reclass.reduceResolution(
    reducer=ee.Reducer.mode(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

###################
# HD
###################
hd_fingerprint_5070 = filter_bands_by_year(hd_fingerprint, CBI_START_YEAR, CBI_END_YEAR).reproject(
    crs=TARGET_CRS,
    scale=4000
)

###################
# Topoterra
###################

# AET (b1) and DEF (b2) for each time slice
tt_early_aet   = topoterra_early.select('b1').rename('tt_early_aet')
tt_early_def   = topoterra_early.select('b2').rename('tt_early_def')

tt_later_aet   = topoterra_later.select('b1').rename('tt_later_aet')
tt_later_def   = topoterra_later.select('b2').rename('tt_later_def')

tt_normals_aet = topoterra_normals.select('b1').rename('tt_normal_aet')
tt_normals_def = topoterra_normals.select('b2').rename('tt_normal_def')

tt_future_aet  = topoterra_future.select('b1').rename('tt_future_aet')
tt_future_def  = topoterra_future.select('b2').rename('tt_future_def')

# Change bands: early - future
tt_change_aet = tt_future_aet.subtract(tt_early_aet).rename('tt_change_aet')
tt_change_def = tt_future_def.subtract(tt_early_def).rename('tt_change_def')

# Combine everything into one image
topoterra_image = ee.Image.cat([
    tt_early_aet, tt_early_def,
    tt_later_aet, tt_later_def,
    tt_normals_aet, tt_normals_def,
    tt_future_aet, tt_future_def,
    tt_change_aet, tt_change_def
])

print("Topoterra bands:", topoterra_image.bandNames().getInfo())

topoterra_5070 = topoterra_image.reproject(
    crs=TARGET_CRS,
    scale=SCALE)

###################
# TERRACLIMATE
###################

# Terraclimate AET and DEF
terraclimate_mean_5070 = terraclimate.select(['aet', 'def']) \
    .filter(ee.Filter.calendarRange(1984, 2020, 'year')) \
    .mean() \
    .reproject(crs=TARGET_CRS,
               scale=4000)

# Define the functions to compute annual and summer terraclimate means
def annual_terraclimate_image(index):

    def annual_terraclimate_images(year):
        year = ee.Number(year)
        mean_image = terraclimate \
            .filter(ee.Filter.calendarRange(year, year, 'year')) \
            .select(index) \
            .mean() \
            .rename(ee.String(index).cat('_annual_').cat(year.format()))
        return mean_image

    annual_images = years.map(annual_terraclimate_images)
    annual_collection = ee.ImageCollection(annual_images)
    #annual_image = annual_collection.toBands()
    annual_image = toBands_with_projection(annual_collection)
    annual_image = remove_to_bands_append(annual_image)
    return(annual_image)

def summer_terraclimate_image(index):
    def summer_mean_image(year):
        year = ee.Number(year)
        # Filter for June (6), July (7), August (8) of that year
        summer_months = terraclimate \
            .filter(ee.Filter.calendarRange(year, year, 'year')) \
            .filter(ee.Filter.calendarRange(6, 8, 'month')) \
            .select(index) \
            .mean() \
            .rename(ee.String(index).cat('_summer_').cat(year.format()))
        return summer_months

    summer_images = years.map(summer_mean_image)
    summer_collection = ee.ImageCollection(summer_images)
    summer_image = toBands_with_projection(summer_collection)
    summer_image = remove_to_bands_append(summer_image)
    return summer_image


pdsi_annual_5070 = (annual_terraclimate_image('pdsi').
               reproject(
                    crs=TARGET_CRS,
                    scale=4000
                ))
pdsi_summer_5070 = (summer_terraclimate_image('pdsi').
               reproject(
                    crs=TARGET_CRS,
                    scale=4000
                ))
vpd_annual_5070 = (annual_terraclimate_image('vpd').
               reproject(
                    crs=TARGET_CRS,
                    scale=4000
                ))
vpd_summer_5070 = (summer_terraclimate_image('vpd').
               reproject(
                    crs=TARGET_CRS,
                    scale=4000
                ))

print("PDSI annual bands:", pdsi_annual_5070.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Topoterra bands: ['tt_early_aet', 'tt_early_def', 'tt_later_aet', 'tt_later_def', 'tt_normal_aet', 'tt_normal_def', 'tt_future_aet', 'tt_future_def', 'tt_change_aet', 'tt_change_def']
# PDSI annual bands: ['pdsi_annual_1985', 'pdsi_annual_1986', 'pdsi_annual_1987', 'pdsi_annual_1988', 'pdsi_annual_1989', 'pdsi_annual_1990', 'pdsi_annual_1991', 'pdsi_annual_1992', 'pdsi_annual_1993', 'pdsi_annual_1994', 'pdsi_annual_1995', 'pdsi_annual_1996', 'pdsi_annual_1997', 'pdsi_annual_1998', 'pdsi_annual_1999', 'pdsi_annual_2000', 'pdsi_annual_2001', 'pdsi_annual_2002', 'pdsi_annual_2003', 'pdsi_annual_2004', 'pdsi_annual_2005', 'pdsi_annual_2006', 'pdsi_annual_2007', 'pdsi_annual_2008', 'pdsi_annual_2009', 'pdsi_annual_2010', 'pdsi_annual_2011', 'pdsi_annual_2012', 'pdsi_annual_2013', 'pdsi_annual_2014', 'pdsi_annual_2015', 'pdsi_annual_2016', 'pdsi_annual_2017', 'pdsi_annual_2018', 'pdsi_annual_2019', 'pdsi_annual_2020']

# %%
###################
# PREP USFS DATA
###################

usfs_perc_5070 = usfs.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

usfs_mask_5070 = (usfs_perc_5070
                  .gte(MINIMUM_USFS_PERC_PIXEL)
                  .selfMask())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
###################
# PREP FIRE DATA
###################

print("CBI bands:", cbi.bandNames().getInfo())

# Fire mask
fire_mask = (cbi
             .mask()
             .reduce(ee.Reducer.sum().unweighted())
             .gt(0)
             .rename('valid')
             .unmask(0))

fire_mask_perc_5070 = fire_mask.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

fire_mask_5070 = (fire_mask_perc_5070
                  .gte(MINIMUM_FIRE_PERC_PIXEL)
                  .selfMask()
                  .unmask(0))



# CBI filled versions
cbi_filled_neg = cbi.unmask(-1)
cbi_filled_zeros = cbi.unmask(0)

# CBI resampled to 5070 at SCALE
cbi_filled_zeros_5070 = cbi_filled_zeros.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

cbi_filled_neg_5070 = cbi_filled_neg.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

########################
# CREATE MOVING WINDOW & RESAMPLED DATASETS
########################

# CBI Moving window
cbi_mw_mean = moving_window(image=cbi_filled_zeros, window_size=500, kernel_shape='circle', reducer=ee.Reducer.mean(), keep_original_bandnames=True)
cbi_mw_mean = insert_to_band_names(image = cbi_mw_mean, text='500mmwmean_', index=-9)
cbi_mw_mean_5070 = cbi_mw_mean.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)

cbi_mw_std = moving_window(image=cbi_filled_zeros, window_size=500, kernel_shape='circle', reducer=ee.Reducer.stdDev(), keep_original_bandnames=True)
cbi_mw_std = insert_to_band_names(image=cbi_mw_std, text='500mmwstd_', index=-9)
cbi_mw_std_5070 = cbi_mw_std.reduceResolution(
    reducer=ee.Reducer.mean(),
    maxPixels=1024
).reproject(
    crs=TARGET_CRS,
    scale=SCALE
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# CBI bands: ['cbi_year_1985', 'cbi_year_1986', 'cbi_year_1987', 'cbi_year_1988', 'cbi_year_1989', 'cbi_year_1990', 'cbi_year_1991', 'cbi_year_1992', 'cbi_year_1993', 'cbi_year_1994', 'cbi_year_1995', 'cbi_year_1996', 'cbi_year_1997', 'cbi_year_1998', 'cbi_year_1999', 'cbi_year_2000', 'cbi_year_2001', 'cbi_year_2002', 'cbi_year_2003', 'cbi_year_2004', 'cbi_year_2005', 'cbi_year_2006', 'cbi_year_2007', 'cbi_year_2008', 'cbi_year_2009', 'cbi_year_2010', 'cbi_year_2011', 'cbi_year_2012', 'cbi_year_2013', 'cbi_year_2014', 'cbi_year_2015', 'cbi_year_2016', 'cbi_year_2017', 'cbi_year_2018', 'cbi_year_2019', 'cbi_year_2020']

# %%
# # # TEST FIXED DATA GENERATION STEPS

# test_area = (
#     ee.FeatureCollection("TIGER/2018/Counties")
#     .filter(ee.Filter.eq("NAME", "Jefferson"))
#     .filter(ee.Filter.eq("STATEFP", "08"))  # Colorado
#     .geometry()
# )

# # # Use visualization copies here
# # modis_clipped = vcf_5070.clip(test_area).select("vcf_tree_2000")
# # rap_mosaic_clipped = rap_mosaic.clip(test_area).select("rap_tree_2000")
# # rap_reduced_clipped = rap_5070.clip(test_area).select("rap_tree_2000")
# # biotic_clipped = biotic_5070.clip(test_area).select("biotic_2000")
# # combined_forest_clipped = combined_forest.clip(test_area)
# # combined_forest_perc_5070_clipped = combined_forest_perc_5070.clip(test_area)
# combined_forest_mask_5070_clipped = combined_forest_mask_5070.clip(test_area)
# # nfg_clipped = nfg_5070.clip(test_area)
# # conservative_forest_annual_clipped = conservative_forest_year_after.clip(test_area).select("forest_after_2000")
# # unburned_forest_distance_clipped = unburned_forest_distance.clip(test_area).select("distance_forest_after_2000")
# # unburned_forest_distance_5070_clipped = unburned_forest_distance_5070.clip(test_area).select("distance_forest_after_2000")

# # cbi_clipped = cbi.clip(test_area).select("cbi_year_2000")
# # cbi_5070_clipped = cbi_5070.clip(test_area).select("cbi_year_2000")
# # cbi_mw_mean_clipped = cbi_mw_mean.clip(test_area).select("cbi_500mmwmean_year_2000")
# # cbi_mw_std_clipped = cbi_mw_std.clip(test_area).select("cbi_500mmwstd_year_2000")
# # cbi_mw_mean_5070_clipped = cbi_mw_mean_5070.clip(test_area).select("cbi_500mmwmean_year_2000")
# # cbi_mw_std_5070_clipped = cbi_mw_std_5070.clip(test_area).select("cbi_500mmwstd_year_2000")

# # fire_mask_5070_clipped = fire_mask_5070.clip(test_area).select("valid")
# # fire_mask_perc_5070_clipped = fire_mask_perc_5070.clip(test_area).select("valid")

# # cbi_vis = {
# #     "min": 0,
# #     "max": 3,
# #     "palette": [
# #         "#0000ff",  # 0
# #         "#00ff00",
# #         "#ffff00",
# #         "#ff7f00",
# #         "#ff0000"   # 3
# #     ]
# # }

# m = geemap.Map(center=[40.05, -105.35], zoom=9)
# # # m.addLayer(modis_clipped, {"min": 0, "max": 100}, "MODIS vcf_tree")
# # # m.addLayer(rap_mosaic_clipped, {"min": 0, "max": 100}, "RAP mosaic rap_tree")
# # # m.addLayer(rap_reduced_clipped, {"min": 0, "max": 100}, "RAP reduced rap_tree")
# # # m.addLayer(biotic_clipped, {"min": 0, "max": 1}, "Biotic 2010")
# # # m.addLayer(combined_forest_clipped, {"min": 0, "max": 1}, "Combined forest")
# m.addLayer(combined_forest_mask_5070_clipped, {"min": 0, "max": 1}, "Combined forest mask 5070")
# # # m.addLayer(nfg_clipped, {"min": 0, "max": 1}, "NFG 5070")
# # # m.addLayer(unburned_forest_distance_clipped, {"min": 0, "max": 1000}, "Unburned forest distance")
# # # m.addLayer(conservative_forest_annual_clipped, {"min": 0, "max": 1}, "Conservative forest annual 2000")
# # # m.addLayer(unburned_forest_distance_5070_clipped, {"min": 0, "max": 1000}, "Unburned forest distance 5070")
# # m.addLayer(cbi_clipped, cbi_vis, "CBI 2000")   
# # m.addLayer(cbi_5070_clipped, cbi_vis, "CBI 5070 2000")
# # # m.addLayer(cbi_mw_mean_clipped, cbi_vis, "CBI 500mmwmean 2000")
# # # m.addLayer(cbi_mw_std_clipped, cbi_vis, "CBI 500mmwstd 2000")
# # # m.addLayer(cbi_mw_mean_5070_clipped, cbi_vis, "CBI 500mmwmean 5070 2000")
# # # m.addLayer(cbi_mw_std_5070_clipped, cbi_vis, "CBI 500mmwstd 5070 2000")
# # m.addLayer(fire_mask_perc_5070_clipped, {"min": 0, "max": 1}, "Fire mask perc 5070")
# # m.addLayer(fire_mask_5070_clipped, {"min": 0, "max": 1}, "Fire mask 5070")
# m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# CREATE SAMPLE

# # Mask to the ROI
# coords_img = ee.Image.pixelCoordinates(biotic_sum.projection())
# masked_coords = coords_img.updateMask(biotic_sum.mask())

# # Sample pixel centers (creates FeatureCollection with geometries)
# sample_points = masked_coords.sample(
#     region=aoi,
#     scale=1000,
#     geometries=True
# )


# print('test sample size:', sample_points.size().getInfo())

# Map = geemap.Map(center=[0, 0], zoom=2)
# Map.addLayer(biotic_sum_1997_2007, {'min': 0, 'max': 100, 'palette': ['blue', 'yellow', 'red']}, 'Biotic Sum 1997-2007')
# Map.addLayer(sample_points, {}, 'Sample Points')
# Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Map = geemap.Map(center=[40.0, -105.5], zoom=11)

# # Add forest percentage image
# Map.addLayer(forest_perc_coarse, {
#     'min': 0, 'max': 100, 'palette': ['white', 'green']
# }, 'Forest % (Coarse)')

# Map.addLayer(fire_mask, {
#     'min': 0, 'max': 1, 'palette': ['white', 'red']
# }, 'Fire Mask')

# # Add forest mask
# Map.addLayer(combined_forest_mask.updateMask(combined_forest_mask), {
#     'palette': ['darkgreen']
# }, 'Combined Forest Mask')

# # Add coarse sample points
# #Map.addLayer(fc_coarse, {}, 'Coarse Sample Points')

#Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# # EXTRACTION

# fc = sample_points
# fc_coarse = sample_points

# # Do direct extraction and filter of forest and fire
# # fc = extract_single_band_value(combined_forest_mask, fc, 'forest').filter(ee.Filter.eq('forest', 1))
# # fc = extract_single_band_value(fire_mask, fc, 'fire')

# fire_only = fc.filter(ee.Filter.And(
#     ee.Filter.eq('forest', 1),
#     ee.Filter.eq('fire', 1)
# ))
# forest_only = fc.filter(ee.Filter.And(
#     ee.Filter.eq('forest', 1),
#     ee.Filter.eq('fire', 0)
# ))

# forest_sample = forest_only.randomColumn('rand', seed=RANDOM_SEED).filter(ee.Filter.lt('rand', FOREST_RANDOM_SAMPLE))
# combined = fire_only.merge(forest_sample)

# # Add variables to points
# # Define (image, label) pairs
# image_label_pairs = [
#     (srtm, 'srtm'),
#     (tpi, 'tpi'),
#     (frg_reclass, 'frg_reclass'),
#     (chili, 'chili'),
#     (lf_bps_img, 'lf_bps'),
#     (biotic_sum, 'biotic_sum')
# ]

# # Apply the extraction function
# for img, label in image_label_pairs:
#     fc = extract_single_band_value(img, fc, label)



# # Add multi-band data using reduceRegions
# # List of images to reduce
# multiband_images = [cbi, biotic, rap_mosaic, treemap, terraclimate_mean, \
#                     pdsi_annual, pdsi_summer, \
#                     # vpd_annual, vpd_summer, \
#                     hd_fingerprint, \
#                     # hd_z_def, hd_z_pdsi, hd_z_vpd, hd_z_tmmx, hd_z_soil, hd_z_pr, \
#                     cbi_mw_median, cbi_mw_std, unburned_forest_distance]

# # Apply reduceRegions for each image
# for img in multiband_images:
#     fc = img.reduceRegions(collection=fc, reducer=ee.Reducer.first(), scale=30)


# # Do coarse extraction
# #fc_coarse = extract_single_band_value(forest_perc_coarse, fc_coarse, 'forest').filter(ee.Filter.gt('forest', COARSE_FOREST_PERC_MIN))
# #fc_coarse = extract_single_band_value(forest_cover_max, fc_coarse, 'forest').filter(ee.Filter.gt('forest', COARSE_TRE_MAX_MIN))


# # Add variables to coarse points
# # Define (image, label) pairs for coarse extraction
# image_label_pairs_coarse = [
#     #(fire_perc_coarse, 'fire'),
#     (srtm_coarse, 'srtm'),
#     (tpi_coarse, 'tpi'),
#     (frg_reclass_coarse, 'frg_reclass'),
#     (chili_coarse, 'chili'),
#     (lf_bps_img_coarse, 'lf_bps'),
#     (biotic_sum, 'biotic_sum')
# ]


# # Apply the extraction function
# for img, label in image_label_pairs_coarse:
#     fc_coarse = extract_single_band_value(img, fc_coarse, label)


# # Multiband extraction for coarse data
# multiband_images_coarse = [ cbi_coarse, biotic, rap_mosaic_coarse, treemap_coarse, terraclimate_mean, \
#     pdsi_annual, pdsi_summer, \
#     # vpd_annual, vpd_summer, \
#     hd_fingerprint, \
#     # hd_z_def, hd_z_pdsi, hd_z_vpd, hd_z_tmmx, hd_z_soil, hd_z_pr, \
#     cbi_mw_median_coarse, cbi_mw_std_coarse, unburned_forest_distance_coarse]

# # Apply reduceRegions for each image
# for img in multiband_images_coarse:
#     fc_coarse = img.reduceRegions(collection=fc_coarse, reducer=ee.Reducer.first(), scale=30)





# # Round to minimize string sizes in CSVs
# def round_fc(feature_collection):
#     def round_feature(feat):
#         props = feat.toDictionary()
#         keys = ee.List(props.keys())

#         def keep_if_tenths(key):
#             key_str = ee.String(key)
#             cond1 = key_str.slice(0, 7).equals('biotic_')
#             cond2 = key_str.slice(0, 4).equals('cbi_')
#             return ee.Algorithms.If(cond1, key, ee.Algorithms.If(cond2, key, None))

#         def keep_if_ints(key):
#             key_str = ee.String(key)
#             cond1 = key_str.slice(0, 4).equals('aet')
#             cond2 = key_str.slice(0, 4).equals('def')
#             cond3 = key_str.slice(0, 9).equals('distance_')
#             cond4 = key_str.slice(0, 5).equals('pdsi_')
#             cond5 = key_str.slice(0, 4).equals('vpd_')
#             return ee.Algorithms.If(cond1, key,
#                 ee.Algorithms.If(cond2, key,
#                 ee.Algorithms.If(cond3, key,
#                 ee.Algorithms.If(cond4, key,
#                 ee.Algorithms.If(cond5, key, None)))))

#         round_tenths = keys.map(keep_if_tenths).removeAll([None])
#         round_int = keys.map(keep_if_ints).removeAll([None])

#         def round_tenths_fn(key):
#             val = ee.Number(props.get(key)).multiply(10).round().divide(10)
#             return ee.List([key, val])

#         def round_int_fn(key):
#             val = ee.Number(props.get(key)).round()
#             return ee.List([key, val])

#         updates_tenths = round_tenths.map(round_tenths_fn)
#         updates_int = round_int.map(round_int_fn)

#         updates_tenths_dict = ee.Dictionary(ee.List(updates_tenths).flatten())
#         updates_int_dict = ee.Dictionary(ee.List(updates_int).flatten())

#         all_updates = updates_tenths_dict.combine(updates_int_dict, overwrite=True)
#         return feat.set(all_updates)

#     return feature_collection.map(round_feature)

# fc = round_fc(fc)
# fc_coarse = round_fc(fc_coarse)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Test the feature collections

# first_feature = fc.first()
# property_names = first_feature.propertyNames()
# print('Property names:', property_names.getInfo())
# print(first_feature.getInfo())
# print(len(property_names.getInfo()))

# first_coarse_feature = fc_coarse.first()
# coarse_property_names = first_coarse_feature.propertyNames()
# print('Coarse property names:', coarse_property_names.getInfo())
# print(first_coarse_feature.getInfo())
# print(len(coarse_property_names.getInfo()))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
##################### DEPRECATED - DOESN'T BATCH GEOGRAPHICALLY #####################

# # Get estimated size of the feature collection based on area of forest in AOI

# # Mask the image to retain only forest (value == 1)
# binary = combined_forest_mask.updateMask(combined_forest_mask.eq(1)).rename('forest')

# # Multiply by pixel area to get area per pixel
# area_image = binary.multiply(ee.Image.pixelArea())

# # Reduce to total area in square meters
# area_stats = area_image.reduceRegion(
#     reducer=ee.Reducer.sum(),
#     geometry=aoi,
#     scale=30,
#     maxPixels=1e13
# )

# # Convert to square kilometers
# forest_area_km2 = ee.Number(area_stats.get('forest')).divide(1e6)
# estimated_partitions = forest_area_km2.multiply(FOREST_RANDOM_SAMPLE).divide(BATCH_SIZE).ceil()

# # Add reproducible random column
# fc = fc.randomColumn('batch_rand', seed=RANDOM_SEED)

# # Define number of partitions (based on estimated size or safe guess)
# num_partitions = estimated_partitions.getInfo()
# step = 1.0 / num_partitions
# print(f"Estimated partitions: {num_partitions}, Step size: {step}")

# # Export loop
# for i in range(num_partitions):
#     print(f"Starting export for batch {i + 1} of {num_partitions}")
#     lower = i * step
#     upper = (i + 1) * step
#     subset = fc.filter(ee.Filter.And(
#         ee.Filter.gte('batch_rand', lower),
#         ee.Filter.lt('batch_rand', upper)
#     ))

#     task = ee.batch.Export.table.toDrive(
#         collection=subset,
#         description=f'fc_export_batch_{AOI_READABLE}_btchsz{BATCH_SIZE}_{i}',
#         folder=DRIVE_FOLDER,
#         fileNamePrefix=f'fc_batch_{AOI_READABLE}_btchsz{BATCH_SIZE}_{i}',
#         fileFormat='CSV'
#     )
#     task.start()






########## DEPRECATED - NEED TO BATCH ############
# # Export fine-resolution feature collection
# task_fc = ee.batch.Export.table.toDrive(
#     collection=fc,
#     description=f'fc_{AOI_READABLE}',
#     fileFormat='CSV',
#     folder=DRIVE_FOLDER, 
#     fileNamePrefix=f'fc_{AOI_READABLE}'
# )
# task_fc.start()

# # Export coarse-resolution feature collection
# task_fc_coarse = ee.batch.Export.table.toDrive(
#     collection=fc_coarse,
#     description= f'fc_coarse_{AOI_READABLE}',
#     fileFormat='CSV',
#     folder=DRIVE_FOLDER,
#     fileNamePrefix= f'fc_coarse_{AOI_READABLE}'
# )
# task_fc_coarse.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Used in extract_additional_data to get lat/long from point features
def add_latlon(feature):
    coords = feature.geometry().transform('EPSG:4326', 1).coordinates() #transform to WGS84 to extract lat/long
    return feature.set({
        'long': coords.get(0),
        'lat': coords.get(1)
    })

# Used in extract_additional_data to extract single band values
def extract_single_band_value(image, collection, new_name):
    new_pts = image.reduceRegions(
        collection=collection,
        reducer=ee.Reducer.first(),
        scale=30
    ).map(lambda pt: pt.set(new_name, pt.get('first')).set('first', None))
    return new_pts


# used in extract_additional_data to keep csv size smaller by rounding certain variables
# note that ugly logic is used because we are using ee objects
def round_fc(feature_collection):
    def round_feature(feat):
        props = feat.toDictionary()
        keys = ee.List(props.keys())

        def keep_if_tenths(key):
            key_str = ee.String(key)
            cond1 = key_str.slice(0, 7).equals('biotic_')
            cond2 = key_str.slice(0, 4).equals('cbi_')
            return ee.Algorithms.If(cond1, key, ee.Algorithms.If(cond2, key, None))

        def keep_if_ints(key):
            key_str = ee.String(key)
            cond1 = key_str.slice(0, 4).equals('aet')
            cond2 = key_str.slice(0, 4).equals('def')
            cond3 = key_str.slice(0, 9).equals('distance_')
            cond4 = key_str.slice(0, 5).equals('pdsi_')
            cond5 = key_str.slice(0, 4).equals('vpd_')
            cond6 = key_str.slice(0, 3).equals('tt_')
            cond7 = key_str.slice(0, 4).equals('srtm')
            cond8 = key_str.slice(0, 3).equals('tpi')
            cond9 = key_str.slice(0, 5).equals('chili')
            cond10 = key_str.slice(0, 9).equals('rap_tree_')
            return ee.Algorithms.If(cond1, key,
                ee.Algorithms.If(cond2, key,
                ee.Algorithms.If(cond3, key,
                ee.Algorithms.If(cond4, key,
                ee.Algorithms.If(cond5, key,
                ee.Algorithms.If(cond6, key,
                ee.Algorithms.If(cond7, key,
                ee.Algorithms.If(cond8, key,
                ee.Algorithms.If(cond9, key,
                ee.Algorithms.If(cond10, key, None))))))))))

        round_tenths = keys.map(keep_if_tenths).removeAll([None])
        round_int = keys.map(keep_if_ints).removeAll([None])

        def round_tenths_fn(key):
            val = ee.Number(props.get(key)).multiply(10).round().divide(10)
            return ee.List([key, val])

        def round_int_fn(key):
            val = ee.Number(props.get(key)).round()
            return ee.List([key, val])

        updates_tenths = round_tenths.map(round_tenths_fn)
        updates_int = round_int.map(round_int_fn)

        updates_tenths_dict = ee.Dictionary(ee.List(updates_tenths).flatten())
        updates_int_dict = ee.Dictionary(ee.List(updates_int).flatten())

        all_updates = updates_tenths_dict.combine(updates_int_dict, overwrite=True)
        return feat.set(all_updates)

    return feature_collection.map(round_feature)



# Function to extract additional data for points of interest from both single-band and multi-band images
def extract_additional_data(fc_interest, tile_geom):
    # Add variables to points
    # Define (image, label) pairs
    image_label_pairs = [
        (srtm_5070, 'srtm'),
        (tpi_5070, 'tpi'),
        (frg_reclass_5070, 'frg_reclass'),
        (nfg_5070, 'nfg'),
        (chili_5070, 'chili')
    ]

    # Apply the extraction function
    for img, label in image_label_pairs:
        img_clipped = img.clip(tile_geom)
        fc_interest = extract_single_band_value(img_clipped, fc_interest, label)



    # Add multi-band data using reduceRegions
    # List of images to reduce
    multiband_images = ([biotic_5070,
                        terraclimate_mean_5070, topoterra_5070,
                        cbi_filled_neg_5070, # use filled version to avoid NaNs
                        cbi_mw_mean_5070, cbi_mw_std_5070, 
                        rap_5070, vcf_5070, #response variables
                        pdsi_annual_5070, pdsi_summer_5070,
                        # vpd_annual, vpd_summer,
                        hd_fingerprint_5070,
                        # hd_z_def, hd_z_pdsi, hd_z_vpd, hd_z_tmmx, hd_z_soil, hd_z_pr,
                        unburned_forest_distance_5070])

    # Apply reduceRegions for each image
    for img_m in multiband_images:
        img_clipped_m = img_m.clip(tile_geom)
        fc_interest = img_clipped_m.reduceRegions(collection=fc_interest, reducer=ee.Reducer.first(), scale=30, tileScale = 4)

    fc_interest = round_fc(fc_interest)
    fc_interest = fc_interest.map(add_latlon)

    # fc_interest = attach_polygon_properties_to_points(
    #     samples_fc=fc_interest,
    #     polygons_fc=epa_lvl4,
    #     property_names=['us_l3code', 'us_l3name', 'us_l4code', 'us_l4name'])

    return fc_interest


#######################################################
# PRIMARY OPERATING FUNCTION FOR TILE-BASED EXTRACTION
#######################################################
def extract(tile_geom):
    target_tile = vcf_5070.clip(tile_geom).select(0).add(1)  # add 1 to avoid zero-mask issues; use the first vcf band
    coords_img = ee.Image.pixelCoordinates(target_tile.projection())
    masked_coords = coords_img.updateMask(target_tile.mask())

    # Sample pixel centers (creates FeatureCollection with geometries)
    sample_points = masked_coords.sample(
        region=tile_geom,
        scale=SAMPLE_SCALE,
        geometries=True
    )

    fc = sample_points

    # Limit sample to forested USFS lands. Take a subsample of unburned areas and all burned areas.
    fc = extract_single_band_value(usfs_mask_5070, fc, 'usfs').filter(ee.Filter.eq('usfs', 1))
    fc = extract_single_band_value(combined_forest_mask_5070, fc, 'forest').filter(ee.Filter.eq('forest', 1))
    fc = extract_single_band_value(fire_mask_5070, fc, 'fire')

    fire_only = fc.filter(ee.Filter.And(
        ee.Filter.eq('forest', 1),
        ee.Filter.eq('fire', 1)
    ))
    forest_only = fc.filter(ee.Filter.And(
        ee.Filter.eq('forest', 1),
        ee.Filter.eq('fire', 0)
    ))

    forest_sample = forest_only.randomColumn('rand', seed=RANDOM_SEED).filter(ee.Filter.lt('rand', FOREST_RANDOM_SAMPLE))
    fc_interest = fire_only.merge(forest_sample)

    # Conditional extraction to avoid processing empty collections
    result = ee.Algorithms.If(
        fc_interest.size().gt(0),
        extract_additional_data(fc_interest, tile_geom),
        ee.FeatureCollection([])  # Return empty collection if no features
    )

    return(result)






# def attach_polygon_properties_to_points(samples_fc, polygons_fc, property_names):
#     def add_props(point):
#         intersected = polygons_fc.filterBounds(point.geometry()).first()
#         def set_props(f):
#             return point.set({prop: f.get(prop) for prop in property_names})
#         return ee.Algorithms.If(intersected, set_props(intersected), point)
    
#     return samples_fc.map(add_props)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# used to create tile IDs for exports
def format_tile_id(f):
    # Use the feature's geometry directly instead of .bounds()
    geom4326 = f.geometry().transform('EPSG:4326', 1)
    coords = ee.List(geom4326.coordinates().get(0))
    
    # For a rectangle from coveringGrid, ring is usually [LL, LR, UR, UL, LL]
    upper_left = ee.List(coords.get(3))

    def format_coord(num):
        num = ee.Number(num)
        prefix = ee.Algorithms.If(num.gte(0), 'p', 'n')
        # encode 3 decimal places without a dot, as before
        abs_val = num.abs().multiply(1000).round().format('%d')
        safe_val = abs_val.replace('.', '')
        return ee.String(prefix).cat(safe_val)

    lon_str = format_coord(upper_left.get(0))
    lat_str = format_coord(upper_left.get(1))
    tile_id = lon_str.cat(lat_str)

    return f.set('tile_id', tile_id)

# # Create samples and export in batches
# # This needs to be done fully server-side to prevent creation
# # of the entire feature collection in memory, which hits memory limitations

aoi_bounds = aoi.geometry().bounds()
grid = aoi_bounds.coveringGrid(ee.Projection(TARGET_CRS).atScale(TILE_SIZE))
grid = grid.map(format_tile_id)


#####################################
# Loop through tiles and extract data
#####################################

grid_list = grid.toList(grid.size())
num_tiles = grid.size().getInfo()

# Operational export
for i in range(num_tiles):
    tile = ee.Feature(grid_list.get(i))
    tile_geom = tile.geometry()
    tile_id = tile.get('tile_id').getInfo()

    fc_tile = extract(tile_geom)

    # Export tile points
    print(f"Submitted export for tile {tile_id}")
    task = ee.batch.Export.table.toDrive(
        collection=fc_tile,
        description=f'fc_tile_{AOI_READABLE}_{tile_id}',
        folder=DRIVE_FOLDER,
        fileNamePrefix=f'fc_tile_{AOI_READABLE}_{tile_id}',
        fileFormat='CSV'
    )
    task.start()


# # TESTING 
# for i in range(5):
#     tile = ee.Feature(grid_list.get(i))
#     tile_geom = tile.geometry()
#     tile_id = tile.get('tile_id').getInfo()

#     fc_tile = extract(tile_geom)
#     # property_names = ee.FeatureCollection(fc_tile).first().propertyNames()
#     # print('Property names:', property_names.getInfo())
#     # print(ee.FeatureCollection(fc_tile).first().getInfo())

#     # Export tile points
#     print(f"Submitted export for tile {tile_id}")
#     task = ee.batch.Export.table.toDrive(
#         collection=fc_tile,
#         description=f'TEST2fc_tile_{AOI_READABLE}_{tile_id}',
#         folder=DRIVE_FOLDER,
#         fileNamePrefix=f'TEST2fc_tile_{AOI_READABLE}_{tile_id}',
#         fileFormat='CSV'
#     )
#     task.start()

#     # asset_id = f"{'projects/ee-tymc5571-multi-disturbance/assets'}/TEST2fc_tile_{AOI_READABLE}_{tile_id}"

#     # task = ee.batch.Export.table.toAsset(
#     #     collection=fc_tile,
#     #     description=f'TEST2fc_tile_{AOI_READABLE}_{tile_id}',
#     #     assetId=asset_id
#     # )
#     # task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Submitted export for tile n13427p3256
# Submitted export for tile n14179p3244
# Submitted export for tile n14058p3261
# Submitted export for tile n13936p3278
# Submitted export for tile n13814p3294
# Submitted export for tile n13693p3311
# Submitted export for tile n13571p3327
# Submitted export for tile n13449p3344
# Submitted export for tile n14810p3245
# Submitted export for tile n14689p3263
# Submitted export for tile n14567p3280
# Submitted export for tile n14446p3297
# Submitted export for tile n14324p3315
# Submitted export for tile n14203p3332
# Submitted export for tile n14081p3349
# Submitted export for tile n13959p3366
# Submitted export for tile n13838p3382
# Submitted export for tile n13716p3399
# Submitted export for tile n13594p3416
# Submitted export for tile n13472p3432
# Submitted export for tile n15441p3243
# Submitted export for tile n15320p3261
# Submitted export for tile n15199p3279
# Submitted export for tile n15077p3297
# Submitted export for tile n14956p3315
# Submitted export for tile n14835p3333
# Submitted export for tile n14713p3350
# Submitted export for tile n14592p3368
# Submitted export for tile n14470p3385
# Submitted export for tile n14348p3402
# Submitted export for tile n14226p3420
# Submitted export for tile n14105p3437
# Submitted export for tile n13983p3454
# Submitted export for tile n13861p3470
# Submitted export for tile n13739p3487
# Submitted export for tile n13617p3504
# Submitted export for tile n13495p3520
# Submitted export for tile n15951p3257
# Submitted export for tile n15830p3276
# Submitted export for tile n15709p3294
# Submitted export for tile n15588p3313
# Submitted export for tile n15466p3331
# Submitted export for tile n15345p3349
# Submitted export for tile n15224p3367
# Submitted export for tile n15102p3385
# Submitted export for tile n14981p3403
# Submitted export for tile n14859p3421
# Submitted export for tile n14737p3438
# Submitted export for tile n14616p3456
# Submitted export for tile n14494p3473
# Submitted export for tile n14372p3490
# Submitted export for tile n14250p3508
# Submitted export for tile n14128p3525
# Submitted export for tile n14006p3542
# Submitted export for tile n13884p3558
# Submitted export for tile n13762p3575
# Submitted export for tile n13640p3592
# Submitted export for tile n13517p3608
# Submitted export for tile n13395p3624
# Submitted export for tile n16461p3269
# Submitted export for tile n16340p3288
# Submitted export for tile n16219p3307
# Submitted export for tile n16098p3326
# Submitted export for tile n15977p3345
# Submitted export for tile n15856p3363
# Submitted export for tile n15735p3382
# Submitted export for tile n15613p3400
# Submitted export for tile n15492p3419
# Submitted export for tile n15370p3437
# Submitted export for tile n15249p3455
# Submitted export for tile n15127p3473
# Submitted export for tile n15005p3491
# Submitted export for tile n14884p3508
# Submitted export for tile n14762p3526
# Submitted export for tile n14640p3544
# Submitted export for tile n14518p3561
# Submitted export for tile n14396p3578
# Submitted export for tile n14274p3596
# Submitted export for tile n14152p3613
# Submitted export for tile n14029p3630
# Submitted export for tile n13907p3646
# Submitted export for tile n13785p3663
# Submitted export for tile n13663p3680
# Submitted export for tile n13540p3696
# Submitted export for tile n13418p3713
# Submitted export for tile n16488p3357
# Submitted export for tile n16367p3376
# Submitted export for tile n16246p3395
# Submitted export for tile n16124p3414
# Submitted export for tile n16003p3432
# Submitted export for tile n15882p3451
# Submitted export for tile n15760p3470
# Submitted export for tile n15639p3488
# Submitted export for tile n15517p3506
# Submitted export for tile n15395p3525
# Submitted export for tile n15274p3543
# Submitted export for tile n15152p3561
# Submitted export for tile n15030p3579
# Submitted export for tile n14908p3596
# Submitted export for tile n14786p3614
# Submitted export for tile n14664p3632
# Submitted export for tile n14542p3649
# Submitted export for tile n14420p3666
# Submitted export for tile n14298p3683
# Submitted export for tile n14175p3701
# Submitted export for tile n14053p3718
# Submitted export for tile n13931p3734
# Submitted export for tile n13808p3751
# Submitted export for tile n13686p3768
# Submitted export for tile n13563p3784
# Submitted export for tile n13440p3801
# Submitted export for tile n16514p3444
# Submitted export for tile n16393p3463
# Submitted export for tile n16272p3482
# Submitted export for tile n16150p3501
# Submitted export for tile n16029p3520
# Submitted export for tile n15907p3539
# Submitted export for tile n15786p3557
# Submitted export for tile n15664p3576
# Submitted export for tile n15542p3594
# Submitted export for tile n15421p3612
# Submitted export for tile n15299p3630
# Submitted export for tile n15177p3648
# Submitted export for tile n15055p3666
# Submitted export for tile n14933p3684
# Submitted export for tile n14811p3702
# Submitted export for tile n14688p3719
# Submitted export for tile n14566p3737
# Submitted export for tile n14444p3754
# Submitted export for tile n14321p3771
# Submitted export for tile n14199p3789
# Submitted export for tile n14077p3806
# Submitted export for tile n13954p3822
# Submitted export for tile n13831p3839
# Submitted export for tile n13709p3856
# Submitted export for tile n13586p3872
# Submitted export for tile n13463p3889
# Submitted export for tile n16541p3532
# Submitted export for tile n16420p3551
# Submitted export for tile n16298p3570
# Submitted export for tile n16177p3589
# Submitted export for tile n16055p3608
# Submitted export for tile n15933p3626
# Submitted export for tile n15812p3645
# Submitted export for tile n15690p3663
# Submitted export for tile n15568p3682
# Submitted export for tile n15446p3700
# Submitted export for tile n15324p3718
# Submitted export for tile n15202p3736
# Submitted export for tile n15080p3754
# Submitted export for tile n14957p3772
# Submitted export for tile n14835p3790
# Submitted export for tile n14713p3807
# Submitted export for tile n14590p3825
# Submitted export for tile n14468p3842
# Submitted export for tile n14345p3859
# Submitted export for tile n14223p3877
# Submitted export for tile n14100p3894
# Submitted export for tile n13977p3911
# Submitted export for tile n13855p3927
# Submitted export for tile n13732p3944
# Submitted export for tile n13609p3961
# Submitted export for tile n13486p3977
# Submitted export for tile n16446p3638
# Submitted export for tile n16325p3657
# Submitted export for tile n16203p3676
# Submitted export for tile n16081p3695
# Submitted export for tile n15959p3714
# Submitted export for tile n15837p3733
# Submitted export for tile n15715p3751
# Submitted export for tile n15593p3770
# Submitted export for tile n15471p3788
# Submitted export for tile n15349p3806
# Submitted export for tile n15227p3824
# Submitted export for tile n15105p3842
# Submitted export for tile n14982p3860
# Submitted export for tile n14860p3878
# Submitted export for tile n14737p3895
# Submitted export for tile n14615p3913
# Submitted export for tile n14492p3930
# Submitted export for tile n14369p3947
# Submitted export for tile n14247p3965
# Submitted export for tile n14124p3982
# Submitted export for tile n14001p3999
# Submitted export for tile n13878p4015
# Submitted export for tile n13755p4032
# Submitted export for tile n13632p4049
# Submitted export for tile n13509p4065
# Submitted export for tile n13386p4082
# Submitted export for tile n16473p3726
# Submitted export for tile n16351p3745
# Submitted export for tile n16229p3764
# Submitted export for tile n16107p3783
# Submitted export for tile n15985p3802
# Submitted export for tile n15863p3820
# Submitted export for tile n15741p3839
# Submitted export for tile n15619p3857
# Submitted export for tile n15497p3876
# Submitted export for tile n15374p3894
# Submitted export for tile n15252p3912
# Submitted export for tile n15129p3930
# Submitted export for tile n15007p3948
# Submitted export for tile n14884p3966
# Submitted export for tile n14762p3983
# Submitted export for tile n14639p4001
# Submitted export for tile n14516p4018
# Submitted export for tile n14393p4035
# Submitted export for tile n14271p4053
# Submitted export for tile n14148p4070
# Submitted export for tile n14025p4087
# Submitted export for tile n13902p4103
# Submitted export for tile n13778p4120
# Submitted export for tile n13655p4137
# Submitted export for tile n13532p4153
# Submitted export for tile n13409p4170
# Submitted export for tile n16499p3813
# Submitted export for tile n16378p3833
# Submitted export for tile n16256p3852
# Submitted export for tile n16133p3871
# Submitted export for tile n16011p3889
# Submitted export for tile n15889p3908
# Submitted export for tile n15767p3927
# Submitted export for tile n15644p3945
# Submitted export for tile n15522p3963
# Submitted export for tile n15400p3982
# Submitted export for tile n15277p4000
# Submitted export for tile n15154p4018
# Submitted export for tile n15032p4036
# Submitted export for tile n14909p4053
# Submitted export for tile n14786p4071
# Submitted export for tile n14663p4089
# Submitted export for tile n14541p4106
# Submitted export for tile n14418p4123
# Submitted export for tile n14295p4141
# Submitted export for tile n14171p4158
# Submitted export for tile n14048p4175
# Submitted export for tile n13925p4192
# Submitted export for tile n13802p4208
# Submitted export for tile n13678p4225
# Submitted export for tile n13555p4242
# Submitted export for tile n13431p4258
# Submitted export for tile n16526p3901
# Submitted export for tile n16404p3920
# Submitted export for tile n16282p3939
# Submitted export for tile n16160p3958
# Submitted export for tile n16037p3977
# Submitted export for tile n15915p3996
# Submitted export for tile n15793p4014
# Submitted export for tile n15670p4033
# Submitted export for tile n15548p4051
# Submitted export for tile n15425p4069
# Submitted export for tile n15302p4088
# Submitted export for tile n15180p4106
# Submitted export for tile n15057p4124
# Submitted export for tile n14934p4141
# Submitted export for tile n14811p4159
# Submitted export for tile n14688p4177
# Submitted export for tile n14565p4194
# Submitted export for tile n14442p4211
# Submitted export for tile n14319p4229
# Submitted export for tile n14195p4246
# Submitted export for tile n14072p4263
# Submitted export for tile n13949p4280
# Submitted export for tile n13825p4297
# Submitted export for tile n13702p4313
# Submitted export for tile n13578p4330
# Submitted export for tile n13454p4346
# Submitted export for tile n16553p3989
# Submitted export for tile n16431p4008
# Submitted export for tile n16308p4027
# Submitted export for tile n16186p4046
# Submitted export for tile n16064p4065
# Submitted export for tile n15941p4083
# Submitted export for tile n15819p4102
# Submitted export for tile n15696p4121
# Submitted export for tile n15573p4139
# Submitted export for tile n15450p4157
# Submitted export for tile n15328p4175
# Submitted export for tile n15205p4193
# Submitted export for tile n15082p4211
# Submitted export for tile n14959p4229
# Submitted export for tile n14836p4247
# Submitted export for tile n14712p4265
# Submitted export for tile n14589p4282
# Submitted export for tile n14466p4299
# Submitted export for tile n14343p4317
# Submitted export for tile n14219p4334
# Submitted export for tile n14096p4351
# Submitted export for tile n13972p4368
# Submitted export for tile n13849p4385
# Submitted export for tile n13725p4401
# Submitted export for tile n13601p4418
# Submitted export for tile n13477p4434
# Submitted export for tile n16458p4095
# Submitted export for tile n16335p4115
# Submitted export for tile n16213p4133
# Submitted export for tile n16090p4152
# Submitted export for tile n15967p4171
# Submitted export for tile n15845p4190
# Submitted export for tile n15722p4208
# Submitted export for tile n15599p4227
# Submitted export for tile n15476p4245
# Submitted export for tile n15353p4263
# Submitted export for tile n15230p4281
# Submitted export for tile n15107p4299
# Submitted export for tile n14984p4317
# Submitted export for tile n14860p4335
# Submitted export for tile n14737p4353
# Submitted export for tile n14614p4370
# Submitted export for tile n14490p4388
# Submitted export for tile n14367p4405
# Submitted export for tile n14243p4422
# Submitted export for tile n14120p4439
# Submitted export for tile n13996p4456
# Submitted export for tile n13872p4473
# Submitted export for tile n13748p4490
# Submitted export for tile n13624p4506
# Submitted export for tile n13500p4523
# Submitted export for tile n13376p4539
# Submitted export for tile n16484p4183
# Submitted export for tile n16362p4202
# Submitted export for tile n16239p4221
# Submitted export for tile n16116p4240
# Submitted export for tile n15993p4259
# Submitted export for tile n15871p4278
# Submitted export for tile n15748p4296
# Submitted export for tile n15625p4315
# Submitted export for tile n15502p4333
# Submitted export for tile n15378p4351
# Submitted export for tile n15255p4369
# Submitted export for tile n15132p4387
# Submitted export for tile n15009p4405
# Submitted export for tile n14885p4423
# Submitted export for tile n14762p4441
# Submitted export for tile n14638p4458
# Submitted export for tile n14515p4476
# Submitted export for tile n14391p4493
# Submitted export for tile n14267p4510
# Submitted export for tile n14143p4527
# Submitted export for tile n14020p4544
# Submitted export for tile n13896p4561
# Submitted export for tile n13772p4578
# Submitted export for tile n13648p4594
# Submitted export for tile n13524p4611
# Submitted export for tile n13399p4627
# Submitted export for tile n16511p4271
# Submitted export for tile n16388p4290
# Submitted export for tile n16266p4309
# Submitted export for tile n16143p4328
# Submitted export for tile n16020p4347
# Submitted export for tile n15897p4365
# Submitted export for tile n15774p4384
# Submitted export for tile n15650p4402
# Submitted export for tile n15527p4421
# Submitted export for tile n15404p4439
# Submitted export for tile n15281p4457
# Submitted export for tile n15157p4475
# Submitted export for tile n15034p4493
# Submitted export for tile n14910p4511
# Submitted export for tile n14786p4529
# Submitted export for tile n14663p4546
# Submitted export for tile n14539p4564
# Submitted export for tile n14415p4581
# Submitted export for tile n14291p4598
# Submitted export for tile n14167p4615
# Submitted export for tile n14043p4632
# Submitted export for tile n13919p4649
# Submitted export for tile n13795p4666
# Submitted export for tile n13671p4683
# Submitted export for tile n13547p4699
# Submitted export for tile n13422p4716
# Submitted export for tile n16538p4358
# Submitted export for tile n16415p4377
# Submitted export for tile n16292p4397
# Submitted export for tile n16169p4416
# Submitted export for tile n16046p4434
# Submitted export for tile n15923p4453
# Submitted export for tile n15800p4472
# Submitted export for tile n15676p4490
# Submitted export for tile n15553p4509
# Submitted export for tile n15430p4527
# Submitted export for tile n15306p4545
# Submitted export for tile n15182p4563
# Submitted export for tile n15059p4581
# Submitted export for tile n14935p4599
# Submitted export for tile n14811p4617
# Submitted export for tile n14687p4634
# Submitted export for tile n14564p4652
# Submitted export for tile n14440p4669
# Submitted export for tile n14316p4686
# Submitted export for tile n14191p4703
# Submitted export for tile n14067p4721
# Submitted export for tile n13943p4737
# Submitted export for tile n13819p4754
# Submitted export for tile n13694p4771
# Submitted export for tile n13570p4787
# Submitted export for tile n13446p4804
# Submitted export for tile n16565p4446
# Submitted export for tile n16442p4465
# Submitted export for tile n16319p4484
# Submitted export for tile n16196p4503
# Submitted export for tile n16072p4522
# Submitted export for tile n15949p4541
# Submitted export for tile n15826p4560
# Submitted export for tile n15702p4578
# Submitted export for tile n15579p4597
# Submitted export for tile n15455p4615
# Submitted export for tile n15331p4633
# Submitted export for tile n15208p4651
# Submitted export for tile n15084p4669
# Submitted export for tile n14960p4687
# Submitted export for tile n14836p4705
# Submitted export for tile n14712p4722
# Submitted export for tile n14588p4740
# Submitted export for tile n14464p4757
# Submitted export for tile n14340p4774
# Submitted export for tile n14216p4792
# Submitted export for tile n14091p4809
# Submitted export for tile n13967p4826
# Submitted export for tile n13842p4842
# Submitted export for tile n13718p4859
# Submitted export for tile n13593p4876
# Submitted export for tile n13469p4892
# Submitted export for tile n16469p4553
# Submitted export for tile n16346p4572
# Submitted export for tile n16222p4591
# Submitted export for tile n16099p4610
# Submitted export for tile n15975p4629
# Submitted export for tile n15852p4647
# Submitted export for tile n15728p4666
# Submitted export for tile n15605p4684
# Submitted export for tile n15481p4703
# Submitted export for tile n15357p4721
# Submitted export for tile n15233p4739
# Submitted export for tile n15109p4757
# Submitted export for tile n14985p4775
# Submitted export for tile n14861p4793
# Submitted export for tile n14737p4810
# Submitted export for tile n14613p4828
# Submitted export for tile n14488p4845
# Submitted export for tile n14364p4863
# Submitted export for tile n14240p4880
# Submitted export for tile n14115p4897
# Submitted export for tile n13991p4914
# Submitted export for tile n13866p4931
# Submitted export for tile n13741p4947
# Submitted export for tile n13617p4964
# Submitted export for tile n13492p4981
# Submitted export for tile n16496p4641
# Submitted export for tile n16373p4660
# Submitted export for tile n16249p4679
# Submitted export for tile n16126p4698
# Submitted export for tile n16002p4717
# Submitted export for tile n15878p4735
# Submitted export for tile n15754p4754
# Submitted export for tile n15631p4772
# Submitted export for tile n15507p4791
# Submitted export for tile n15383p4809
# Submitted export for tile n15259p4827
# Submitted export for tile n15135p4845
# Submitted export for tile n15010p4863
# Submitted export for tile n14886p4881
# Submitted export for tile n14762p4898
# Submitted export for tile n14637p4916
# Submitted export for tile n14513p4933
# Submitted export for tile n14388p4951
# Submitted export for tile n14264p4968
# Submitted export for tile n14139p4985
# Submitted export for tile n14015p5002
# Submitted export for tile n13890p5019
# Submitted export for tile n13765p5036
# Submitted export for tile n13640p5052
# Submitted export for tile n13515p5069
# Submitted export for tile n13390p5085
# Submitted export for tile n16523p4728
# Submitted export for tile n16399p4747
# Submitted export for tile n16276p4767
# Submitted export for tile n16152p4786
# Submitted export for tile n16028p4804
# Submitted export for tile n15904p4823
# Submitted export for tile n15781p4842
# Submitted export for tile n15657p4860
# Submitted export for tile n15532p4879
# Submitted export for tile n15408p4897
# Submitted export for tile n15284p4915
# Submitted export for tile n15160p4933
# Submitted export for tile n15036p4951
# Submitted export for tile n14911p4969
# Submitted export for tile n14787p4987
# Submitted export for tile n14662p5004
# Submitted export for tile n14538p5022
# Submitted export for tile n14413p5039
# Submitted export for tile n14288p5056
# Submitted export for tile n14163p5073
# Submitted export for tile n14039p5090
# Submitted export for tile n13914p5107
# Submitted export for tile n13789p5124
# Submitted export for tile n13664p5141
# Submitted export for tile n13539p5157
# Submitted export for tile n13413p5174
# Submitted export for tile n16550p4816
# Submitted export for tile n16426p4835
# Submitted export for tile n16303p4854
# Submitted export for tile n16179p4873
# Submitted export for tile n16055p4892
# Submitted export for tile n15931p4911
# Submitted export for tile n15807p4930
# Submitted export for tile n15683p4948
# Submitted export for tile n15558p4967
# Submitted export for tile n15434p4985
# Submitted export for tile n15310p5003
# Submitted export for tile n15185p5021
# Submitted export for tile n15061p5039
# Submitted export for tile n14936p5057
# Submitted export for tile n14812p5075
# Submitted export for tile n14687p5092
# Submitted export for tile n14562p5110
# Submitted export for tile n14437p5127
# Submitted export for tile n14313p5144
# Submitted export for tile n14188p5162
# Submitted export for tile n14063p5179
# Submitted export for tile n13937p5196
# Submitted export for tile n13812p5212
# Submitted export for tile n13687p5229
# Submitted export for tile n13562p5246
# Submitted export for tile n13437p5262
# Submitted export for tile n16454p4923
# Submitted export for tile n16330p4942
# Submitted export for tile n16206p4961
# Submitted export for tile n16081p4980
# Submitted export for tile n15957p4999
# Submitted export for tile n15833p5018
# Submitted export for tile n15709p5036
# Submitted export for tile n15584p5055
# Submitted export for tile n15460p5073
# Submitted export for tile n15335p5091
# Submitted export for tile n15211p5109
# Submitted export for tile n15086p5127
# Submitted export for tile n14961p5145
# Submitted export for tile n14837p5163
# Submitted export for tile n14712p5180
# Submitted export for tile n14587p5198
# Submitted export for tile n14462p5215
# Submitted export for tile n14337p5233
# Submitted export for tile n14212p5250
# Submitted export for tile n14087p5267
# Submitted export for tile n13961p5284
# Submitted export for tile n13836p5301
# Submitted export for tile n13711p5317
# Submitted export for tile n13585p5334
# Submitted export for tile n13460p5351
# Submitted export for tile n16481p5011
# Submitted export for tile n16357p5030
# Submitted export for tile n16232p5049
# Submitted export for tile n16108p5068
# Submitted export for tile n15984p5087
# Submitted export for tile n15859p5105
# Submitted export for tile n15735p5124
# Submitted export for tile n15610p5143
# Submitted export for tile n15486p5161
# Submitted export for tile n15361p5179
# Submitted export for tile n15236p5197
# Submitted export for tile n15112p5215
# Submitted export for tile n14987p5233
# Submitted export for tile n14862p5251
# Submitted export for tile n14737p5269
# Submitted export for tile n14612p5286
# Submitted export for tile n14487p5304
# Submitted export for tile n14361p5321
# Submitted export for tile n14236p5338
# Submitted export for tile n14111p5355
# Submitted export for tile n13985p5372
# Submitted export for tile n13860p5389
# Submitted export for tile n13734p5406
# Submitted export for tile n13609p5422
# Submitted export for tile n13483p5439
# Submitted export for tile n16508p5099
# Submitted export for tile n16384p5118
# Submitted export for tile n16259p5137
# Submitted export for tile n16135p5156
# Submitted export for tile n16010p5175
# Submitted export for tile n15886p5193
# Submitted export for tile n15761p5212
# Submitted export for tile n15637p5231
# Submitted export for tile n15512p5249
# Submitted export for tile n15387p5267
# Submitted export for tile n15262p5285
# Submitted export for tile n15137p5303
# Submitted export for tile n15012p5321
# Submitted export for tile n14887p5339
# Submitted export for tile n14762p5357
# Submitted export for tile n14637p5374
# Submitted export for tile n14511p5392
# Submitted export for tile n14386p5409
# Submitted export for tile n14261p5426
# Submitted export for tile n14135p5444
# Submitted export for tile n14009p5461
# Submitted export for tile n13884p5477
# Submitted export for tile n13758p5494
# Submitted export for tile n13632p5511
# Submitted export for tile n13507p5527
# Submitted export for tile n13381p5544
# Submitted export for tile n16535p5186
# Submitted export for tile n16411p5206
# Submitted export for tile n16286p5225
# Submitted export for tile n16162p5244
# Submitted export for tile n16037p5263
# Submitted export for tile n15912p5281
# Submitted export for tile n15788p5300
# Submitted export for tile n15663p5319
# Submitted export for tile n15538p5337
# Submitted export for tile n15413p5355
# Submitted export for tile n15288p5373
# Submitted export for tile n15163p5392
# Submitted export for tile n15037p5409
# Submitted export for tile n14912p5427
# Submitted export for tile n14787p5445
# Submitted export for tile n14661p5463
# Submitted export for tile n14536p5480
# Submitted export for tile n14411p5498
# Submitted export for tile n14285p5515
# Submitted export for tile n14159p5532
# Submitted export for tile n14034p5549
# Submitted export for tile n13908p5566
# Submitted export for tile n13782p5583
# Submitted export for tile n13656p5599
# Submitted export for tile n13530p5616
# Submitted export for tile n13404p5632
# Submitted export for tile n16562p5274
# Submitted export for tile n16438p5293
# Submitted export for tile n16313p5313
# Submitted export for tile n16189p5332
# Submitted export for tile n16064p5351
# Submitted export for tile n15939p5369
# Submitted export for tile n15814p5388
# Submitted export for tile n15689p5407
# Submitted export for tile n15564p5425
# Submitted export for tile n15439p5443
# Submitted export for tile n15314p5462
# Submitted export for tile n15188p5480
# Submitted export for tile n15063p5498
# Submitted export for tile n14937p5515
# Submitted export for tile n14812p5533
# Submitted export for tile n14686p5551
# Submitted export for tile n14561p5568
# Submitted export for tile n14435p5586
# Submitted export for tile n14309p5603
# Submitted export for tile n14184p5620
# Submitted export for tile n14058p5637
# Submitted export for tile n13932p5654
# Submitted export for tile n13806p5671
# Submitted export for tile n13680p5688
# Submitted export for tile n13554p5704
# Submitted export for tile n13427p5721
# Submitted export for tile n16465p5381
# Submitted export for tile n16340p5400
# Submitted export for tile n16215p5420
# Submitted export for tile n16091p5438
# Submitted export for tile n15965p5457
# Submitted export for tile n15840p5476
# Submitted export for tile n15715p5495
# Submitted export for tile n15590p5513
# Submitted export for tile n15465p5531
# Submitted export for tile n15339p5550
# Submitted export for tile n15214p5568
# Submitted export for tile n15088p5586
# Submitted export for tile n14963p5604
# Submitted export for tile n14837p5621
# Submitted export for tile n14712p5639
# Submitted export for tile n14586p5657
# Submitted export for tile n14460p5674
# Submitted export for tile n14334p5691
# Submitted export for tile n14208p5709
# Submitted export for tile n14082p5726
# Submitted export for tile n13956p5743
# Submitted export for tile n13830p5760
# Submitted export for tile n13704p5776
# Submitted export for tile n13577p5793
# Submitted export for tile n13451p5809
# Submitted export for tile n16492p5469
# Submitted export for tile n16368p5488
# Submitted export for tile n16242p5507
# Submitted export for tile n16117p5526
# Submitted export for tile n15992p5545
# Submitted export for tile n15867p5564
# Submitted export for tile n15742p5583
# Submitted export for tile n15616p5601
# Submitted export for tile n15491p5620
# Submitted export for tile n15365p5638
# Submitted export for tile n15240p5656
# Submitted export for tile n15114p5674
# Submitted export for tile n14988p5692
# Submitted export for tile n14862p5710
# Submitted export for tile n14737p5727
# Submitted export for tile n14611p5745
# Submitted export for tile n14485p5762
# Submitted export for tile n14359p5780
# Submitted export for tile n14233p5797
# Submitted export for tile n14106p5814
# Submitted export for tile n13980p5831
# Submitted export for tile n13854p5848
# Submitted export for tile n13727p5865
# Submitted export for tile n13601p5881
# Submitted export for tile n13474p5898
# Submitted export for tile n16520p5557
# Submitted export for tile n16395p5576
# Submitted export for tile n16270p5595
# Submitted export for tile n16144p5614
# Submitted export for tile n16019p5633
# Submitted export for tile n15894p5652
# Submitted export for tile n15768p5671
# Submitted export for tile n15643p5689
# Submitted export for tile n15517p5708
# Submitted export for tile n15391p5726
# Submitted export for tile n15265p5744
# Submitted export for tile n15140p5762
# Submitted export for tile n15014p5780
# Submitted export for tile n14888p5798
# Submitted export for tile n14762p5816
# Submitted export for tile n14636p5833
# Submitted export for tile n14510p5851
# Submitted export for tile n14383p5868
# Submitted export for tile n14257p5885
# Submitted export for tile n14131p5903
# Submitted export for tile n14004p5920
# Submitted export for tile n13878p5937
# Submitted export for tile n13751p5953
# Submitted export for tile n13625p5970
# Submitted export for tile n13498p5987
# Submitted export for tile n16547p5645
# Submitted export for tile n16422p5664
# Submitted export for tile n16297p5683
# Submitted export for tile n16171p5702
# Submitted export for tile n16046p5721
# Submitted export for tile n15920p5740
# Submitted export for tile n15795p5759
# Submitted export for tile n15669p5777
# Submitted export for tile n15543p5796
# Submitted export for tile n15417p5814
# Submitted export for tile n15291p5832
# Submitted export for tile n15165p5850
# Submitted export for tile n15039p5868
# Submitted export for tile n14913p5886
# Submitted export for tile n14787p5904
# Submitted export for tile n14661p5922
# Submitted export for tile n14534p5939
# Submitted export for tile n14408p5957
# Submitted export for tile n14282p5974
# Submitted export for tile n14155p5991
# Submitted export for tile n14029p6008
# Submitted export for tile n13902p6025
# Submitted export for tile n13775p6042
# Submitted export for tile n13648p6059
# Submitted export for tile n13522p6075
# Submitted export for tile n13395p6092
# Submitted export for tile n16449p5752
# Submitted export for tile n16324p5771
# Submitted export for tile n16198p5790
# Submitted export for tile n16073p5809
# Submitted export for tile n15947p5828
# Submitted export for tile n15821p5847
# Submitted export for tile n15695p5865
# Submitted export for tile n15569p5884
# Submitted export for tile n15443p5902
# Submitted export for tile n15317p5921
# Submitted export for tile n15191p5939
# Submitted export for tile n15065p5957
# Submitted export for tile n14939p5975
# Submitted export for tile n14812p5992
# Submitted export for tile n14686p6010
# Submitted export for tile n14559p6028
# Submitted export for tile n14433p6045
# Submitted export for tile n14306p6062
# Submitted export for tile n14180p6079
# Submitted export for tile n14053p6097
# Submitted export for tile n13926p6114
# Submitted export for tile n13799p6130
# Submitted export for tile n13672p6147
# Submitted export for tile n13545p6164
# Submitted export for tile n13418p6180
# Submitted export for tile n16477p5840
# Submitted export for tile n16351p5859
# Submitted export for tile n16226p5878
# Submitted export for tile n16100p5897
# Submitted export for tile n15974p5916
# Submitted export for tile n15848p5935
# Submitted export for tile n15722p5954
# Submitted export for tile n15596p5972
# Submitted export for tile n15470p5991
# Submitted export for tile n15343p6009
# Submitted export for tile n15217p6027
# Submitted export for tile n15091p6045
# Submitted export for tile n14964p6063
# Submitted export for tile n14838p6081
# Submitted export for tile n14711p6098
# Submitted export for tile n14585p6116
# Submitted export for tile n14458p6133
# Submitted export for tile n14331p6151
# Submitted export for tile n14204p6168
# Submitted export for tile n14077p6185
# Submitted export for tile n13950p6202
# Submitted export for tile n13823p6219
# Submitted export for tile n13696p6236
# Submitted export for tile n13569p6252
# Submitted export for tile n13442p6269
# Submitted export for tile n16504p5928
# Submitted export for tile n16379p5947
# Submitted export for tile n16253p5966
# Submitted export for tile n16127p5985
# Submitted export for tile n16001p6004
# Submitted export for tile n15875p6023
# Submitted export for tile n15748p6042
# Submitted export for tile n15622p6060
# Submitted export for tile n15496p6079
# Submitted export for tile n15369p6097
# Submitted export for tile n15243p6115
# Submitted export for tile n15116p6133
# Submitted export for tile n14990p6151
# Submitted export for tile n14863p6169
# Submitted export for tile n14736p6187
# Submitted export for tile n14610p6204
# Submitted export for tile n14483p6222
# Submitted export for tile n14356p6239
# Submitted export for tile n14229p6256
# Submitted export for tile n14102p6274
# Submitted export for tile n13975p6291
# Submitted export for tile n13847p6308
# Submitted export for tile n13720p6324
# Submitted export for tile n13593p6341
# Submitted export for tile n13465p6357
# Submitted export for tile n16532p6016
# Submitted export for tile n16406p6035
# Submitted export for tile n16280p6055
# Submitted export for tile n16154p6074
# Submitted export for tile n16028p6092
# Submitted export for tile n15901p6111
# Submitted export for tile n15775p6130
# Submitted export for tile n15649p6149
# Submitted export for tile n15522p6167
# Submitted export for tile n15396p6185
# Submitted export for tile n15269p6203
# Submitted export for tile n15142p6222
# Submitted export for tile n15016p6240
# Submitted export for tile n14889p6257
# Submitted export for tile n14762p6275
# Submitted export for tile n14635p6293
# Submitted export for tile n14508p6310
# Submitted export for tile n14381p6328
# Submitted export for tile n14254p6345
# Submitted export for tile n14126p6362
# Submitted export for tile n13999p6379
# Submitted export for tile n13872p6396
# Submitted export for tile n13744p6413
# Submitted export for tile n13617p6430
# Submitted export for tile n13489p6446
# Submitted export for tile n16560p6104
# Submitted export for tile n16434p6123
# Submitted export for tile n16307p6143
# Submitted export for tile n16181p6162
# Submitted export for tile n16055p6181
# Submitted export for tile n15928p6199
# Submitted export for tile n15802p6218
# Submitted export for tile n15675p6237
# Submitted export for tile n15549p6255
# Submitted export for tile n15422p6274
# Submitted export for tile n15295p6292
# Submitted export for tile n15168p6310
# Submitted export for tile n15041p6328
# Submitted export for tile n14914p6346
# Submitted export for tile n14787p6364
# Submitted export for tile n14660p6381
# Submitted export for tile n14533p6399
# Submitted export for tile n14406p6416
# Submitted export for tile n14278p6434
# Submitted export for tile n14151p6451
# Submitted export for tile n14023p6468
# Submitted export for tile n13896p6485
# Submitted export for tile n13768p6502
# Submitted export for tile n13641p6518
# Submitted export for tile n13513p6535
# Submitted export for tile n13385p6551
# Submitted export for tile n16461p6212
# Submitted export for tile n16335p6231
# Submitted export for tile n16208p6250
# Submitted export for tile n16082p6269
# Submitted export for tile n15955p6288
# Submitted export for tile n15829p6306
# Submitted export for tile n15702p6325
# Submitted export for tile n15575p6343
# Submitted export for tile n15448p6362
# Submitted export for tile n15321p6380
# Submitted export for tile n15194p6398
# Submitted export for tile n15067p6416
# Submitted export for tile n14940p6434
# Submitted export for tile n14813p6452
# Submitted export for tile n14685p6470
# Submitted export for tile n14558p6487
# Submitted export for tile n14431p6505
# Submitted export for tile n14303p6522
# Submitted export for tile n14176p6539
# Submitted export for tile n14048p6556
# Submitted export for tile n13920p6573
# Submitted export for tile n13793p6590
# Submitted export for tile n13665p6607
# Submitted export for tile n13537p6624
# Submitted export for tile n13409p6640
# Submitted export for tile n16489p6300
# Submitted export for tile n16362p6319
# Submitted export for tile n16236p6338
# Submitted export for tile n16109p6357
# Submitted export for tile n15982p6376
# Submitted export for tile n15855p6395
# Submitted export for tile n15729p6413
# Submitted export for tile n15602p6432
# Submitted export for tile n15475p6450
# Submitted export for tile n15347p6468
# Submitted export for tile n15220p6487
# Submitted export for tile n15093p6505
# Submitted export for tile n14966p6523
# Submitted export for tile n14838p6541
# Submitted export for tile n14711p6558
# Submitted export for tile n14583p6576
# Submitted export for tile n14456p6593
# Submitted export for tile n14328p6611
# Submitted export for tile n14200p6628
# Submitted export for tile n14073p6645
# Submitted export for tile n13945p6662
# Submitted export for tile n13817p6679
# Submitted export for tile n13689p6696
# Submitted export for tile n13561p6712
# Submitted export for tile n13433p6729
# Submitted export for tile n16517p6388
# Submitted export for tile n16390p6407
# Submitted export for tile n16263p6426
# Submitted export for tile n16136p6445
# Submitted export for tile n16009p6464
# Submitted export for tile n15882p6483
# Submitted export for tile n15755p6502
# Submitted export for tile n15628p6520
# Submitted export for tile n15501p6539
# Submitted export for tile n15374p6557
# Submitted export for tile n15246p6575
# Submitted export for tile n15119p6593
# Submitted export for tile n14991p6611
# Submitted export for tile n14864p6629
# Submitted export for tile n14736p6647
# Submitted export for tile n14609p6664
# Submitted export for tile n14481p6682
# Submitted export for tile n14353p6699
# Submitted export for tile n14225p6717
# Submitted export for tile n14097p6734
# Submitted export for tile n13969p6751
# Submitted export for tile n13841p6768
# Submitted export for tile n13713p6784
# Submitted export for tile n13585p6801
# Submitted export for tile n13456p6818
# Submitted export for tile n16544p6476
# Submitted export for tile n16418p6495
# Submitted export for tile n16291p6514
# Submitted export for tile n16164p6533
# Submitted export for tile n16037p6552
# Submitted export for tile n15909p6571
# Submitted export for tile n15782p6590
# Submitted export for tile n15655p6608
# Submitted export for tile n15528p6627
# Submitted export for tile n15400p6645
# Submitted export for tile n15273p6663
# Submitted export for tile n15145p6682
# Submitted export for tile n15017p6700
# Submitted export for tile n14890p6717
# Submitted export for tile n14762p6735
# Submitted export for tile n14634p6753
# Submitted export for tile n14506p6770
# Submitted export for tile n14378p6788
# Submitted export for tile n14250p6805
# Submitted export for tile n14122p6822
# Submitted export for tile n13994p6839
# Submitted export for tile n16445p6583
# Submitted export for tile n16318p6602
# Submitted export for tile n16191p6622
# Submitted export for tile n16064p6641
# Submitted export for tile n15936p6659
# Submitted export for tile n15809p6678
# Submitted export for tile n15682p6697
# Submitted export for tile n15554p6715
# Submitted export for tile n15427p6734
# Submitted export for tile n15299p6752
# Submitted export for tile n15171p6770
# Submitted export for tile n15043p6788
# Submitted export for tile n14915p6806
# Submitted export for tile n14787p6824
# Submitted export for tile n16473p6671
# Submitted export for tile n16346p6691
# Submitted export for tile n16218p6710
# Submitted export for tile n16091p6729
# Submitted export for tile n15964p6748
# Submitted export for tile n15836p6766
# Submitted export for tile n15708p6785
# Submitted export for tile n15581p6804
# Submitted export for tile n15453p6822
# Submitted export for tile n15325p6840
# Submitted export for tile n16501p6760
# Submitted export for tile n16374p6779
# Submitted export for tile n16246p6798
# Submitted export for tile n16118p6817
# Submitted export for tile n15991p6836

# %%
print(grid.size().getInfo())

print(grid_list.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 1006
# 1006

# %%
Map = geemap.Map(center=[0, 0], zoom=2)
Map.addLayer(aoi, {}, 'aoi')
Map.addLayer(grid, {}, 'Grid Tiles')
Map.addLayer(
    usfs_mask_5070.clip(grid),
    {"min": 0, "max": 1, "palette": ["00000000", "00FF00"]},  # transparent → green
    "USFS Mask 5070"
)

Map.addLayer(
    combined_forest_mask_5070.clip(grid),
    {"min": 0, "max": 1, "palette": ["00000000", "FF8C00"]},  # transparent → dark orange
    "Forest Mask 5070"
)

Map.addLayer(
    fire_mask_5070.clip(grid),
    {"min": 0, "max": 1, "palette": ["00000000", "FF0000"]},  # transparent → red
    "Fire Mask 5070"
)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…
